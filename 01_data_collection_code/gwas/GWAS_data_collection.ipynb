# %% [markdown]
# # GWAS data collection

# %%
import pandas as pd
from collections import Counter, defaultdict
import json
import requests
from tqdm import tqdm
import re
import copy

# %% [markdown]
# Prerequisites:
#
# Obtain the last version of `All associations v1.0.2 - with added ontology annotations, GWAS Catalog study accession numbers and genotyping technology` from GWAS Catalog website:
# https://www.ebi.ac.uk/gwas/docs/file-downloads

# %% [markdown]
# GWAS gives us gene-disease associations, therefore we map genes and diseases.

# %% [markdown]
# ## Opening GWAS `.tsv`

# %%
gwas_df = pd.read_table('gwas_catalog_v1.0.2-associations_e110_r2023-09-10.tsv', dtype=str)

# %%
gwas_df
# Out:
#        DATE ADDED TO CATALOG  PUBMEDID   FIRST AUTHOR        DATE     JOURNAL  \
# 0                 2017-11-30  29059683  Michailidou K  2017-10-23      Nature
# 1                 2017-11-30  29059683  Michailidou K  2017-10-23      Nature
# 2                 2017-11-30  29059683  Michailidou K  2017-10-23      Nature
# 3                 2017-11-30  29059683  Michailidou K  2017-10-23      Nature
# 4                 2017-11-30  29059683  Michailidou K  2017-10-23      Nature
# ...                      ...       ...            ...         ...         ...
# 552111            2023-05-04  35120996        Rhee EP  2022-02-01  Kidney Int
# 552112            2023-05-04  35120996        Rhee EP  2022-02-01  Kidney Int
# 552113            2023-05-04  35120996        Rhee EP  2022-02-01  Kidney Int
# 552114            2023-05-04  35120996        Rhee EP  2022-02-01  Kidney Int
# 552115            2023-05-04  35120996        Rhee EP  2022-02-01  Kidney Int
#
#                                         LINK  \
# 0       www.ncbi.nlm.nih.gov/pubmed/29059683
# 1       www.ncbi.nlm.nih.gov/pubmed/29059683
# 2       www.ncbi.nlm.nih.gov/pubmed/29059683
# 3       www.ncbi.nlm.nih.gov/pubmed/29059683
# 4       www.ncbi.nlm.nih.gov/pubmed/29059683
# ...                                      ...
# 552111  www.ncbi.nlm.nih.gov/pubmed/35120996
# 552112  www.ncbi.nlm.nih.gov/pubmed/35120996
# 552113  www.ncbi.nlm.nih.gov/pubmed/35120996
# 552114  www.ncbi.nlm.nih.gov/pubmed/35120996
# 552115  www.ncbi.nlm.nih.gov/pubmed/35120996
#
#                                                     STUDY  \
# 0       Association analysis identifies 65 new breast ...
# 1       Association analysis identifies 65 new breast ...
# 2       Association analysis identifies 65 new breast ...
# 3       Association analysis identifies 65 new breast ...
# 4       Association analysis identifies 65 new breast ...
# ...                                                   ...
# 552111  Trans-ethnic genome-wide association study of ...
# 552112  Trans-ethnic genome-wide association study of ...
# 552113  Trans-ethnic genome-wide association study of ...
# 552114  Trans-ethnic genome-wide association study of ...
# 552115  Trans-ethnic genome-wide association study of ...
#
#                                             DISEASE/TRAIT  \
# 0                                           Breast cancer
# 1                                           Breast cancer
# 2                                           Breast cancer
# 3                                           Breast cancer
# 4                                           Breast cancer
# ...                                                   ...
# 552111        Asparagine levels in chronic kidney disease
# 552112         Bilirubin levels in chronic kidney disease
# 552113        Biliverdin levels in chronic kidney disease
# 552114  Dimethylguanido valerate levels in chronic kid...
# 552115           Guanine levels in chronic kidney disease
#
#                                       INITIAL SAMPLE SIZE  \
# 0       76,192 European ancestry cases, 63,082 Europea...
# 1       76,192 European ancestry cases, 63,082 Europea...
# 2       76,192 European ancestry cases, 63,082 Europea...
# 3       76,192 European ancestry cases, 63,082 Europea...
# 4       76,192 European ancestry cases, 63,082 Europea...
# ...                                                   ...
# 552111                  822 European ancestry individuals
# 552112                  822 European ancestry individuals
# 552113                  822 European ancestry individuals
# 552114                  822 European ancestry individuals
# 552115                  822 European ancestry individuals
#
#                                   REPLICATION SAMPLE SIZE  ...  \
# 0       46,785 European ancestry cases, 42,892 Europea...  ...
# 1       46,785 European ancestry cases, 42,892 Europea...  ...
# 2       46,785 European ancestry cases, 42,892 Europea...  ...
# 3       46,785 European ancestry cases, 42,892 Europea...  ...
# 4       46,785 European ancestry cases, 42,892 Europea...  ...
# ...                                                   ...  ...
# 552111                                                NaN  ...
# 552112                                                NaN  ...
# 552113                                                NaN  ...
# 552114                                                NaN  ...
# 552115                                                NaN  ...
#
#                PVALUE_MLOG P-VALUE (TEXT) OR or BETA  \
# 0       14.301029995663981           (EA)     0.0483
# 1                     24.0           (EA)     0.2482
# 2        6.096910013008056           (EA)     0.0327
# 3       42.045757490560675           (EA)     0.0878
# 4                     10.0           (EA)     0.0481
# ...                    ...            ...        ...
# 552111  15.522878745280337            NaN       0.18
# 552112  14.522878745280337            NaN       0.31
# 552113  18.221848749616356            NaN       0.27
# 552114  14.522878745280337            NaN        0.6
# 552115   45.69897000433602            NaN       0.28
#
#                       95% CI (TEXT)       PLATFORM [SNPS PASSING QC] CNV  \
# 0        [0.036-0.06] unit increase  Illumina [~ 11800000] (imputed)   N
# 1           [0.2-0.3] unit decrease  Illumina [~ 11800000] (imputed)   N
# 2        [0.02-0.046] unit decrease  Illumina [~ 11800000] (imputed)   N
# 3         [0.075-0.1] unit decrease  Illumina [~ 11800000] (imputed)   N
# 4       [0.033-0.063] unit decrease  Illumina [~ 11800000] (imputed)   N
# ...                             ...                              ...  ..
# 552111    [0.14-0.22] unit increase     Illumina [9097073] (imputed)   N
# 552112    [0.23-0.39] unit increase     Illumina [9097073] (imputed)   N
# 552113    [0.21-0.33] unit increase     Illumina [9097073] (imputed)   N
# 552114    [0.44-0.76] unit increase     Illumina [9097073] (imputed)   N
# 552115    [0.24-0.32] unit increase     Illumina [9097073] (imputed)   N
#
#                        MAPPED_TRAIT                      MAPPED_TRAIT_URI  \
# 0                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 1                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 2                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 3                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 4                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# ...                             ...                                   ...
# 552111       asparagine measurement  http://www.ebi.ac.uk/efo/EFO_0009766
# 552112        bilirubin measurement  http://www.ebi.ac.uk/efo/EFO_0004570
# 552113       biliverdin measurement  http://www.ebi.ac.uk/efo/EFO_0021033
# 552114  carboxylic acid measurement  http://www.ebi.ac.uk/efo/EFO_0010468
# 552115          guanine measurement  http://www.ebi.ac.uk/efo/EFO_0801165
#
#        STUDY ACCESSION         GENOTYPING TECHNOLOGY
# 0           GCST004988  Genome-wide genotyping array
# 1           GCST004988  Genome-wide genotyping array
# 2           GCST004988  Genome-wide genotyping array
# 3           GCST004988  Genome-wide genotyping array
# 4           GCST004988  Genome-wide genotyping array
# ...                ...                           ...
# 552111    GCST90257491  Genome-wide genotyping array
# 552112    GCST90257494  Genome-wide genotyping array
# 552113    GCST90257495  Genome-wide genotyping array
# 552114    GCST90257503  Genome-wide genotyping array
# 552115    GCST90257509  Genome-wide genotyping array
#
# [552116 rows x 38 columns]

# %%
gwas_df.columns
# Out:
# Index(['DATE ADDED TO CATALOG', 'PUBMEDID', 'FIRST AUTHOR', 'DATE', 'JOURNAL',
#        'LINK', 'STUDY', 'DISEASE/TRAIT', 'INITIAL SAMPLE SIZE',
#        'REPLICATION SAMPLE SIZE', 'REGION', 'CHR_ID', 'CHR_POS',
#        'REPORTED GENE(S)', 'MAPPED_GENE', 'UPSTREAM_GENE_ID',
#        'DOWNSTREAM_GENE_ID', 'SNP_GENE_IDS', 'UPSTREAM_GENE_DISTANCE',
#        'DOWNSTREAM_GENE_DISTANCE', 'STRONGEST SNP-RISK ALLELE', 'SNPS',
#        'MERGED', 'SNP_ID_CURRENT', 'CONTEXT', 'INTERGENIC',
#        'RISK ALLELE FREQUENCY', 'P-VALUE', 'PVALUE_MLOG', 'P-VALUE (TEXT)',
#        'OR or BETA', '95% CI (TEXT)', 'PLATFORM [SNPS PASSING QC]', 'CNV',
#        'MAPPED_TRAIT', 'MAPPED_TRAIT_URI', 'STUDY ACCESSION',
#        'GENOTYPING TECHNOLOGY'],
#       dtype='object')

# %%
gwas_short_df = gwas_df[
    [
        'PUBMEDID', 
        'DATE',
        'DISEASE/TRAIT','MAPPED_TRAIT', 'MAPPED_TRAIT_URI',
        'REPORTED GENE(S)', 'MAPPED_GENE'
    ]
].dropna(subset=['MAPPED_GENE', 'MAPPED_TRAIT_URI'])

# %%
gwas_short_df
# Out:
#         PUBMEDID        DATE  \
# 0       29059683  2017-10-23
# 1       29059683  2017-10-23
# 2       29059683  2017-10-23
# 4       29059683  2017-10-23
# 5       29059683  2017-10-23
# ...          ...         ...
# 552111  35120996  2022-02-01
# 552112  35120996  2022-02-01
# 552113  35120996  2022-02-01
# 552114  35120996  2022-02-01
# 552115  35120996  2022-02-01
#
#                                             DISEASE/TRAIT  \
# 0                                           Breast cancer
# 1                                           Breast cancer
# 2                                           Breast cancer
# 4                                           Breast cancer
# 5                                           Breast cancer
# ...                                                   ...
# 552111        Asparagine levels in chronic kidney disease
# 552112         Bilirubin levels in chronic kidney disease
# 552113        Biliverdin levels in chronic kidney disease
# 552114  Dimethylguanido valerate levels in chronic kid...
# 552115           Guanine levels in chronic kidney disease
#
#                        MAPPED_TRAIT                      MAPPED_TRAIT_URI  \
# 0                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 1                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 2                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 4                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 5                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# ...                             ...                                   ...
# 552111       asparagine measurement  http://www.ebi.ac.uk/efo/EFO_0009766
# 552112        bilirubin measurement  http://www.ebi.ac.uk/efo/EFO_0004570
# 552113       biliverdin measurement  http://www.ebi.ac.uk/efo/EFO_0021033
# 552114  carboxylic acid measurement  http://www.ebi.ac.uk/efo/EFO_0010468
# 552115          guanine measurement  http://www.ebi.ac.uk/efo/EFO_0801165
#
#        REPORTED GENE(S)                                        MAPPED_GENE
# 0                    NR                                              FGF10
# 1                    NR                                            KREMEN1
# 2                    NR                                              TRPS1
# 4                    NR                                 PPP4R3A - CATSPERB
# 5                    NR                                        NF2 - CABP7
# ...                 ...                                                ...
# 552111              NaN                                               ASPG
# 552112              NaN            UGT1A9, UGT1A7, UGT1A10, UGT1A8, UGT1A6
# 552113              NaN  UGT1A9, UGT1A5, UGT1A10, UGT1A6, UGT1A7, UGT1A...
# 552114              NaN                                              AGXT2
# 552115              NaN                                             PHYHD1
#
# [503684 rows x 7 columns]

# %% [markdown]
# ### Transforming GWAS records to binary interactions (`gwas_short_binary_df`)

# %%
gwas_short_binary_df = gwas_short_df.copy()

gwas_short_binary_df['gene'] = gwas_short_df['MAPPED_GENE'].apply(
    lambda x: re.split(', | - ', x)
)

gwas_short_binary_df['trait'] = gwas_short_df['MAPPED_TRAIT_URI'].apply(lambda x: x.split(', '))

# %%
gwas_short_binary_df = (
    gwas_short_binary_df
        .explode('trait')
        .explode('gene')
)

# %%
gwas_short_binary_df
# Out:
#         PUBMEDID        DATE  \
# 0       29059683  2017-10-23
# 1       29059683  2017-10-23
# 2       29059683  2017-10-23
# 4       29059683  2017-10-23
# 4       29059683  2017-10-23
# ...          ...         ...
# 552113  35120996  2022-02-01
# 552113  35120996  2022-02-01
# 552113  35120996  2022-02-01
# 552114  35120996  2022-02-01
# 552115  35120996  2022-02-01
#
#                                             DISEASE/TRAIT  \
# 0                                           Breast cancer
# 1                                           Breast cancer
# 2                                           Breast cancer
# 4                                           Breast cancer
# 4                                           Breast cancer
# ...                                                   ...
# 552113        Biliverdin levels in chronic kidney disease
# 552113        Biliverdin levels in chronic kidney disease
# 552113        Biliverdin levels in chronic kidney disease
# 552114  Dimethylguanido valerate levels in chronic kid...
# 552115           Guanine levels in chronic kidney disease
#
#                        MAPPED_TRAIT                      MAPPED_TRAIT_URI  \
# 0                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 1                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 2                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 4                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 4                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# ...                             ...                                   ...
# 552113       biliverdin measurement  http://www.ebi.ac.uk/efo/EFO_0021033
# 552113       biliverdin measurement  http://www.ebi.ac.uk/efo/EFO_0021033
# 552113       biliverdin measurement  http://www.ebi.ac.uk/efo/EFO_0021033
# 552114  carboxylic acid measurement  http://www.ebi.ac.uk/efo/EFO_0010468
# 552115          guanine measurement  http://www.ebi.ac.uk/efo/EFO_0801165
#
#        REPORTED GENE(S)                                        MAPPED_GENE  \
# 0                    NR                                              FGF10
# 1                    NR                                            KREMEN1
# 2                    NR                                              TRPS1
# 4                    NR                                 PPP4R3A - CATSPERB
# 4                    NR                                 PPP4R3A - CATSPERB
# ...                 ...                                                ...
# 552113              NaN  UGT1A9, UGT1A5, UGT1A10, UGT1A6, UGT1A7, UGT1A...
# 552113              NaN  UGT1A9, UGT1A5, UGT1A10, UGT1A6, UGT1A7, UGT1A...
# 552113              NaN  UGT1A9, UGT1A5, UGT1A10, UGT1A6, UGT1A7, UGT1A...
# 552114              NaN                                              AGXT2
# 552115              NaN                                             PHYHD1
#
#             gene                                 trait
# 0          FGF10  http://www.ebi.ac.uk/efo/EFO_0000305
# 1        KREMEN1  http://www.ebi.ac.uk/efo/EFO_0000305
# 2          TRPS1  http://www.ebi.ac.uk/efo/EFO_0000305
# 4        PPP4R3A  http://www.ebi.ac.uk/efo/EFO_0000305
# 4       CATSPERB  http://www.ebi.ac.uk/efo/EFO_0000305
# ...          ...                                   ...
# 552113    UGT1A8  http://www.ebi.ac.uk/efo/EFO_0021033
# 552113    UGT1A4  http://www.ebi.ac.uk/efo/EFO_0021033
# 552113    UGT1A3  http://www.ebi.ac.uk/efo/EFO_0021033
# 552114     AGXT2  http://www.ebi.ac.uk/efo/EFO_0010468
# 552115    PHYHD1  http://www.ebi.ac.uk/efo/EFO_0801165
#
# [837286 rows x 9 columns]

# %% [markdown]
# ## Opening MRCONSO

# %%
mrconso_path = (
    '../../UMLS_Metathesaurus/mrconso_and_semtypes_2022AA_df.pkl'
)

# %%
mrconso_st_df = pd.read_pickle(mrconso_path)

# %% [markdown]
# ## Obtaining mappings for traits from EBI (online)

# %%
gwas_df['MAPPED_TRAIT_URI'].sample(10)
# Out:
# 249534                 http://www.ebi.ac.uk/efo/EFO_0010228
# 423150    http://www.ebi.ac.uk/efo/EFO_0006336, http://w...
# 503297                 http://www.ebi.ac.uk/efo/EFO_0803452
# 142185            http://purl.obolibrary.org/obo/HP_0000155
# 546456                 http://www.ebi.ac.uk/efo/EFO_0004339
# 489979                 http://www.ebi.ac.uk/efo/EFO_0022284
# 274808         http://purl.obolibrary.org/obo/MONDO_0005148
# 479777                 http://www.ebi.ac.uk/efo/EFO_0004612
# 301456    http://www.ebi.ac.uk/efo/EFO_0004574, http://w...
# 478440                 http://www.ebi.ac.uk/efo/EFO_0004340
# Name: MAPPED_TRAIT_URI, dtype: object

# %%
gwas_traits_s_list = gwas_short_df['MAPPED_TRAIT_URI'].apply(lambda x: x.split(', '))

# %%
gwas_traits_list = []
for ch in gwas_traits_s_list:
    gwas_traits_list += ch

# %%
gwas_traits_list = list(set(gwas_traits_list))
len(gwas_traits_list)
# Out:
# 8284

# %%
Counter([p[7:].split('/')[0] for p in gwas_traits_list])
# Out:
# Counter({'www.ebi.ac.uk': 7088,
#          'purl.obolibrary.org': 1187,
#          'www.orpha.net': 9})

# %%
gwas_traits_ebi_list = [l for l in gwas_traits_list if 'ebi' in l]

# %%
gwas_traits_ebi_list[:3]
# Out:
# ['http://www.ebi.ac.uk/efo/EFO_0803182',
#  'http://www.ebi.ac.uk/efo/EFO_0600065',
#  'http://www.ebi.ac.uk/efo/EFO_0021713']

# %%
gwas_ebi_traits_raw_list = []
bad_links = []

for ent in tqdm(gwas_traits_ebi_list[:]):
    link = f'https://www.ebi.ac.uk/ols/api/ontologies/efo/terms?iri={ent}'
    
    try:
        req = requests.get(link).text

        gwas_ebi_traits_raw_list.append(
            json.loads(req)['_embedded']['terms'][0]
        )
    except:
        bad_links.append(ent)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 7088/7088 [50:46<00:00,  2.33it/s]

# %%
len(bad_links)
# Out:
# 292

# %%
bad_links[:2]
# Out:
# ['http://www.ebi.ac.uk/efo/EFO_0022273',
#  'http://www.ebi.ac.uk/efo/EFO_0022245']

# %% [markdown]
# ### Creating mappings dataframe

# %%
gwas_ebi_traits_raw_df = pd.DataFrame(gwas_ebi_traits_raw_list)

# %%
gwas_ebi_traits_raw_df['obo_xref']
# Out:
# 0       [{'database': 'PMID', 'id': '29875488', 'descr...
# 1       [{'database': 'PMID', 'id': '34309184', 'descr...
# 2       [{'database': 'PMID', 'id': '33634981', 'descr...
# 4       [{'database': 'PMID', 'id': '35347128', 'descr...
# 5       [{'database': 'PMID', 'id': '35347128', 'descr...
#                               ...
# 6790    [{'database': 'PMID', 'id': '23823483', 'descr...
# 6791    [{'database': 'PMID', 'id': ' 32355309', 'desc...
# 6792    [{'database': 'PMID', 'id': '34396400', 'descr...
# 6793    [{'database': 'PMID', 'id': '35347128', 'descr...
# 6795    [{'database': 'PMID', 'id': '28240269', 'descr...
# Name: obo_xref, Length: 11438, dtype: object

# %%
gwas_ebi_traits_raw_df['db_ids'] = (
    gwas_ebi_traits_raw_df['annotation']
        .apply(lambda x: x.get('database_cross_reference'))
)

# %%
gwas_ebi_traits_raw_df = (
    gwas_ebi_traits_raw_df
        .dropna(
            subset=['db_ids']
        )
        .explode('db_ids')
)

# %%
gwas_ebi_traits_raw_df['pref'] = gwas_ebi_traits_raw_df['db_ids'].apply(
    lambda x: x.split(':')[0]
)

# %%
gwas_ebi_traits_raw_df['ext_id'] = gwas_ebi_traits_raw_df['db_ids'].apply(
    lambda x: x.split(':')[1] if len(x.split(':')) > 1 else None
)

# %%
gwas_ebi_traits_raw_df['ext_id']
# Out:
# 0        29875488
# 1        34309184
# 2        33634981
# 4        35347128
# 5        35347128
#           ...
# 6790     23823483
# 6791     32355309
# 6792     34396400
# 6793     35347128
# 6795     28240269
# Name: ext_id, Length: 11438, dtype: object

# %%
gwas_ebi_traits_raw_df
# Out:
#                                        iri lang  \
# 0     http://www.ebi.ac.uk/efo/EFO_0803182   en
# 1     http://www.ebi.ac.uk/efo/EFO_0600065   en
# 2     http://www.ebi.ac.uk/efo/EFO_0021713   en
# 4     http://www.ebi.ac.uk/efo/EFO_0800125   en
# 5     http://www.ebi.ac.uk/efo/EFO_0800773   en
# ...                                    ...  ...
# 6790  http://www.ebi.ac.uk/efo/EFO_0010398   en
# 6791  http://www.ebi.ac.uk/efo/EFO_0010749   en
# 6792  http://www.ebi.ac.uk/efo/EFO_0021795   en
# 6793  http://www.ebi.ac.uk/efo/EFO_0800175   en
# 6795  http://www.ebi.ac.uk/efo/EFO_0020373   en
#
#                                             description  \
# 0     [Quantification of transmembrane protein 119 i...
# 1     [Any process that results in a change in state...
# 2     [Quantification of the ratio of 3-Indolepropio...
# 4     [Quantification of the amount of beta-hydroxyi...
# 5     [Quantification of the amount of X-17340 in a ...
# ...                                                 ...
# 6790  [The quantification of sphingomyelin 24:1 leve...
# 6791  [Quantification of some aspect of motor functi...
# 6792  [Infertility caused by fallopian tube damage, ...
# 6793  [Quantification of the amount of quinolinate i...
# 6795  [The determination of the amount of fatty acid...
#
#                          synonyms  \
# 0                              []
# 1                              []
# 2                              []
# 4                              []
# 5                              []
# ...                           ...
# 6790                    [SM 24:1]
# 6791  [motor control measurement]
# 6792                           []
# 6793                           []
# 6795                           []
#
#                                              annotation  \
# 0     {'database_cross_reference': ['PMID:29875488']...
# 1     {'database_cross_reference': ['PMID:34309184']...
# 2     {'database_cross_reference': ['PMID:33634981']...
# 4     {'database_cross_reference': ['PMID:35347128']...
# 5     {'database_cross_reference': ['PMID:35347128']...
# ...                                                 ...
# 6790  {'database_cross_reference': ['PMID:23823483']...
# 6791  {'database_cross_reference': ['PMID: 32355309'...
# 6792  {'creator': ['Zoe May Pendlington'], 'database...
# 6793  {'database_cross_reference': ['PMID:35347128']...
# 6795  {'database_cross_reference': ['PMID:28240269']...
#
#                                               label ontology_name  \
# 0             transmembrane protein 119 measurement           efo
# 1                             response to tolvaptan           efo
# 2     3-Indolepropionic acid to Hippuric acid ratio           efo
# 4               beta-hydroxyisovalerate measurement           efo
# 5                               X-17340 measurement           efo
# ...                                             ...           ...
# 6790                 sphingomyelin 24:1 measurement           efo
# 6791                     motor function measurement           efo
# 6792                       tubal factor infertility           efo
# 6793                        quinolinate measurement           efo
# 6795  fatty acid-binding protein, heart measurement           efo
#
#      ontology_prefix                      ontology_iri  is_obsolete  ...  \
# 0                EFO  http://www.ebi.ac.uk/efo/efo.owl        False  ...
# 1                EFO  http://www.ebi.ac.uk/efo/efo.owl        False  ...
# 2                EFO  http://www.ebi.ac.uk/efo/efo.owl        False  ...
# 4                EFO  http://www.ebi.ac.uk/efo/efo.owl        False  ...
# 5                EFO  http://www.ebi.ac.uk/efo/efo.owl        False  ...
# ...              ...                               ...          ...  ...
# 6790             EFO  http://www.ebi.ac.uk/efo/efo.owl        False  ...
# 6791             EFO  http://www.ebi.ac.uk/efo/efo.owl        False  ...
# 6792             EFO  http://www.ebi.ac.uk/efo/efo.owl        False  ...
# 6793             EFO  http://www.ebi.ac.uk/efo/efo.owl        False  ...
# 6795             EFO  http://www.ebi.ac.uk/efo/efo.owl        False  ...
#
#            obo_id  in_subset  obo_definition_citation  \
# 0     EFO:0803182       None                     None
# 1     EFO:0600065       None                     None
# 2     EFO:0021713       None                     None
# 4     EFO:0800125       None                     None
# 5     EFO:0800773       None                     None
# ...           ...        ...                      ...
# 6790  EFO:0010398       None                     None
# 6791  EFO:0010749       None                     None
# 6792  EFO:0021795       None                     None
# 6793  EFO:0800175       None                     None
# 6795  EFO:0020373       None                     None
#
#                                                obo_xref obo_synonym  \
# 0     [{'database': 'PMID', 'id': '29875488', 'descr...        None
# 1     [{'database': 'PMID', 'id': '34309184', 'descr...        None
# 2     [{'database': 'PMID', 'id': '33634981', 'descr...        None
# 4     [{'database': 'PMID', 'id': '35347128', 'descr...        None
# 5     [{'database': 'PMID', 'id': '35347128', 'descr...        None
# ...                                                 ...         ...
# 6790  [{'database': 'PMID', 'id': '23823483', 'descr...        None
# 6791  [{'database': 'PMID', 'id': ' 32355309', 'desc...        None
# 6792  [{'database': 'PMID', 'id': '34396400', 'descr...        None
# 6793  [{'database': 'PMID', 'id': '35347128', 'descr...        None
# 6795  [{'database': 'PMID', 'id': '28240269', 'descr...        None
#
#      is_preferred_root                                             _links  \
# 0                False  {'self': {'href': 'https://www.ebi.ac.uk/ols/a...
# 1                False  {'self': {'href': 'https://www.ebi.ac.uk/ols/a...
# 2                False  {'self': {'href': 'https://www.ebi.ac.uk/ols/a...
# 4                False  {'self': {'href': 'https://www.ebi.ac.uk/ols/a...
# 5                False  {'self': {'href': 'https://www.ebi.ac.uk/ols/a...
# ...                ...                                                ...
# 6790             False  {'self': {'href': 'https://www.ebi.ac.uk/ols/a...
# 6791             False  {'self': {'href': 'https://www.ebi.ac.uk/ols/a...
# 6792             False  {'self': {'href': 'https://www.ebi.ac.uk/ols/a...
# 6793             False  {'self': {'href': 'https://www.ebi.ac.uk/ols/a...
# 6795             False  {'self': {'href': 'https://www.ebi.ac.uk/ols/a...
#
#               db_ids  pref     ext_id
# 0      PMID:29875488  PMID   29875488
# 1      PMID:34309184  PMID   34309184
# 2      PMID:33634981  PMID   33634981
# 4      PMID:35347128  PMID   35347128
# 5      PMID:35347128  PMID   35347128
# ...              ...   ...        ...
# 6790   PMID:23823483  PMID   23823483
# 6791  PMID: 32355309  PMID   32355309
# 6792   PMID:34396400  PMID   34396400
# 6793   PMID:35347128  PMID   35347128
# 6795   PMID:28240269  PMID   28240269
#
# [11438 rows x 25 columns]

# %%
gwas_ebi_traits_raw_df[
    gwas_ebi_traits_raw_df['pref'] == 'UMLS'
]
# Out:
#                                        iri lang  \
# 19    http://www.ebi.ac.uk/efo/EFO_0003870   en
# 42    http://www.ebi.ac.uk/efo/EFO_0004145   en
# 89    http://www.ebi.ac.uk/efo/EFO_1000824   en
# 95    http://www.ebi.ac.uk/efo/EFO_0004286   en
# 99    http://www.ebi.ac.uk/efo/EFO_0003060   en
# ...                                    ...  ...
# 6719  http://www.ebi.ac.uk/efo/EFO_0006859   en
# 6759  http://www.ebi.ac.uk/efo/EFO_1001506   en
# 6762  http://www.ebi.ac.uk/efo/EFO_0006788   en
# 6766  http://www.ebi.ac.uk/efo/EFO_0000284   en
# 6783  http://www.ebi.ac.uk/efo/EFO_0004277   en
#
#                                             description  \
# 19    [A congenital or acquired aneurysm within the ...
# 42    [A disease of the muscle in which the muscle f...
# 89    [A disorder caused by a lack of blood flow or ...
# 95    [Occlusion of the lumen of a vein by a thrombu...
# 99    [A group of at least three distinct histologic...
# ...                                                 ...
# 6719  [A primary or metastatic malignant neoplasm af...
# 6759  [An angle-closure glaucoma characterized by cl...
# 6762  [A category of psychiatric disorders which are...
# 6766  [Increase in constituent cells in the PROSTATE...
# 6783  [Tissue NECROSIS in any area of the brain, inc...
#
#                                                synonyms  \
# 19    [Artery Aneurysms, Basilar, Aneurysm, Intracra...
# 42                                           [myopathy]
# 89    [perinatal depression, Asphyxia - birth, Unspe...
# 95                        [VTE, venous thromboembolism]
# 99    [non-small cell carcinoma of lung, NSCLC - non...
# ...                                                 ...
# 6719  [malignant neoplasm of the head and neck, head...
# 6759  [primary angle-closure glaucoma, primary angle...
# 6762  [anxiety disorder, neurotic anxiety states, an...
# 6766  [Adenomas, Prostatic, Benign Hyperplasia of Pr...
# 6783  [ANTERIOR CEREBRAL CIRC INFARCT, Infarction, A...
#
#                                              annotation  \
# 19    {'database_cross_reference': ['DOID:10941', 'U...
# 42    {'comment': ['Editor note: TODO check this, re...
# 89    {'comment': ['Pathophysiology: There are three...
# 95    {'database_cross_reference': ['MedDRA:10066899...
# 99    {'IAO_0000589': ['non-small cell lung carcinom...
# ...                                                 ...
# 6719  {'closeMatch': ['http://identifiers.org/mesh/D...
# 6759  {'database_cross_reference': ['ICD9:365.2', 'U...
# 6762  {'database_cross_reference': ['NCIt:C2878', 'D...
# 6766  {'IAO_0000589': ['benign prostatic hyperplasia...
# 6783  {'database_cross_reference': ['DOID:3454', 'IC...
#
#                                   label ontology_name ontology_prefix  \
# 19                       brain aneurysm           efo             EFO
# 42                             myopathy           efo             EFO
# 89                  asphyxia neonatorum           efo             EFO
# 95               venous thromboembolism           efo             EFO
# 99        non-small cell lung carcinoma           efo             EFO
# ...                                 ...           ...             ...
# 6719  head and neck malignant neoplasia           efo             EFO
# 6759     primary angle closure glaucoma           efo             EFO
# 6762                   anxiety disorder           efo             EFO
# 6766       benign prostatic hyperplasia           efo             EFO
# 6783                   brain infarction           efo             EFO
#
#                           ontology_iri  is_obsolete  ...       obo_id  \
# 19    http://www.ebi.ac.uk/efo/efo.owl        False  ...  EFO:0003870
# 42    http://www.ebi.ac.uk/efo/efo.owl        False  ...  EFO:0004145
# 89    http://www.ebi.ac.uk/efo/efo.owl        False  ...  EFO:1000824
# 95    http://www.ebi.ac.uk/efo/efo.owl        False  ...  EFO:0004286
# 99    http://www.ebi.ac.uk/efo/efo.owl        False  ...  EFO:0003060
# ...                                ...          ...  ...          ...
# 6719  http://www.ebi.ac.uk/efo/efo.owl        False  ...  EFO:0006859
# 6759  http://www.ebi.ac.uk/efo/efo.owl        False  ...  EFO:1001506
# 6762  http://www.ebi.ac.uk/efo/efo.owl        False  ...  EFO:0006788
# 6766  http://www.ebi.ac.uk/efo/efo.owl        False  ...  EFO:0000284
# 6783  http://www.ebi.ac.uk/efo/efo.owl        False  ...  EFO:0004277
#
#         in_subset                            obo_definition_citation  \
# 19           None  [{'definition': 'A congenital or acquired aneu...
# 42           None  [{'definition': 'A disease of the muscle in wh...
# 89    [gard_rare]  [{'definition': 'A disorder caused by a lack o...
# 95           None  [{'definition': 'Occlusion of the lumen of a v...
# 99           None  [{'definition': 'A group of at least three dis...
# ...           ...                                                ...
# 6719         None  [{'definition': 'A primary or metastatic malig...
# 6759         None  [{'definition': 'An angle-closure glaucoma cha...
# 6762         None  [{'definition': 'A category of psychiatric dis...
# 6766         None  [{'definition': 'A non-cancerous nodular enlar...
# 6783         None  [{'definition': 'Tissue necrosis in any area o...
#
#                                                obo_xref  \
# 19    [{'database': 'UMLS', 'id': 'C0007766', 'descr...
# 42    [{'database': 'ICD9', 'id': '359.8', 'descript...
# 89    [{'database': 'DOID', 'id': '11088', 'descript...
# 95    [{'database': 'ICD10', 'id': 'I82', 'descripti...
# 99    [{'database': 'MONDO', 'id': '0005233', 'descr...
# ...                                                 ...
# 6719  [{'database': 'MedDRA', 'id': '10067821', 'des...
# 6759  [{'database': 'ICD9', 'id': '365.20', 'descrip...
# 6762  [{'database': 'NCIt', 'id': 'C2878', 'descript...
# 6766  [{'database': 'MONDO', 'id': '0010811', 'descr...
# 6783  [{'database': 'SNOMEDCT', 'id': '230698000', '...
#
#                                             obo_synonym is_preferred_root  \
# 19    [{'name': 'brain aneurysm', 'scope': 'hasExact...             False
# 42    [{'name': 'myopathy', 'scope': 'hasExactSynony...             False
# 89    [{'name': 'perinatal depression', 'scope': 'ha...             False
# 95    [{'name': 'venous thromboembolism', 'scope': '...             False
# 99    [{'name': 'NSCLC - non-small cell lung cancer'...             False
# ...                                                 ...               ...
# 6719  [{'name': 'cancer of head and neck', 'scope': ...             False
# 6759  [{'name': 'primary angle closure glaucoma', 's...             False
# 6762  [{'name': 'anxiety disorder', 'scope': 'hasExa...             False
# 6766  [{'name': 'benign hyperplasia of prostate', 's...             False
# 6783  [{'name': 'brain infarction', 'scope': 'hasExa...             False
#
#                                                  _links         db_ids  pref  \
# 19    {'self': {'href': 'https://www.ebi.ac.uk/ols/a...  UMLS:C0007766  UMLS
# 42    {'self': {'href': 'https://www.ebi.ac.uk/ols/a...  UMLS:C0026848  UMLS
# 89    {'self': {'href': 'https://www.ebi.ac.uk/ols/a...  UMLS:C0004045  UMLS
# 95    {'self': {'href': 'https://www.ebi.ac.uk/ols/a...  UMLS:C1861172  UMLS
# 99    {'self': {'href': 'https://www.ebi.ac.uk/ols/a...  UMLS:C0007131  UMLS
# ...                                                 ...            ...   ...
# 6719  {'self': {'href': 'https://www.ebi.ac.uk/ols/a...  UMLS:C0278996  UMLS
# 6759  {'self': {'href': 'https://www.ebi.ac.uk/ols/a...  UMLS:C0017606  UMLS
# 6762  {'self': {'href': 'https://www.ebi.ac.uk/ols/a...  UMLS:C0003469  UMLS
# 6766  {'self': {'href': 'https://www.ebi.ac.uk/ols/a...  UMLS:C1704272  UMLS
# 6783  {'self': {'href': 'https://www.ebi.ac.uk/ols/a...  UMLS:C0751955  UMLS
#
#         ext_id
# 19    C0007766
# 42    C0026848
# 89    C0004045
# 95    C1861172
# 99    C0007131
# ...        ...
# 6719  C0278996
# 6759  C0017606
# 6762  C0003469
# 6766  C1704272
# 6783  C0751955
#
# [384 rows x 25 columns]

# %%
gwas_ebi_traits_raw_df['pref'].value_counts()
# Out:
# PMID                                           4851
# MedDRA                                          673
# ICD9                                            604
# MONDO                                           475
# NCIt                                            471
# SNOMEDCT                                        460
# DOID                                            419
# MeSH                                            417
# SCTID                                           407
# NCIT                                            385
# UMLS                                            384
# MESH                                            356
# OMIM                                            345
# ICD10                                           336
# Orphanet                                        159
# GARD                                            120
# ICD10CM                                         116
# EFO                                              87
# HP                                               86
# Wikipedia                                        50
# ONCOTREE                                         45
# ICDO                                             29
# OMIMPS                                           23
# https                                            21
# http                                             17
# CMO                                              15
# KEGG                                             14
# COHD                                             12
# MP                                                9
# ORDO                                              8
# NIFSTD                                            7
# ORCID                                             6
# ICD10WHO                                          5
# CSP                                               4
# ICD10EXP                                          2
# PERSON                                            2
# ICD9CM                                            2
# MO                                                2
# HGNC                                              2
# Quantification of ethanolamine in a sample.       1
# MTH                                               1
# NPO                                               1
# doi                                               1
# NCIm                                              1
# OGMS                                              1
# OMIT                                              1
# PR                                                1
# OBI                                               1
# GO                                                1
# modelled on http                                  1
# VT                                                1
# Name: pref, dtype: int64

# %%
# come from: https://www.nlm.nih.gov/research/umls/sourcereleasedocs/index.html

# keys refer to gwas_ebi_traits_raw_df['pref'], values refer to Metathesaurus SAB column

umls_external_codes = {
    'ICD9': ['ICD9CM', 'MTHICD9'],
    'MedDRA': ['MDR'],
    'ICD10': ['ICD10'],
    #'UMLS': ['MTHMST'],
    'NCIt': ['NCI'],
    'NCIT': ['NCI'],
    'MeSH': ['MSH'],
    'MESH': ['MSH'],
    'ICD10CM': ['ICD10CM'],
    'SNOMEDCT': ['SNOMEDCT_US'],
    'OMIM': ['OMIM'],
}

# %%
gwas_ebi_traits_raw_df.to_pickle(
    'gwas_ebi_traits_raw_df.pkl'
)

# %%
gwas_ebi_traits_raw_df = pd.read_pickle('gwas_ebi_traits_raw_df.pkl')

# %% [markdown]
# ### Splitting mappings to UMLS (direct) and non-UMLS (mrconso)

# %%
gwas_ebi_traits_umls_subs_cui_df = (
    gwas_ebi_traits_raw_df[
        gwas_ebi_traits_raw_df['pref'] == 'UMLS'
    ]
)

gwas_ebi_traits_umls_subs_noncui_df = (
    gwas_ebi_traits_raw_df[
        gwas_ebi_traits_raw_df['pref'].isin(umls_external_codes.keys())
    ]
)

# %% [markdown]
# #### Direct mappings to UMLS

# %%
ebi_link_to_umls_dict = (
    gwas_ebi_traits_umls_subs_cui_df
    [['iri', 'ext_id']]
    .groupby('iri')
    .agg(set)
    ['ext_id']
    .to_dict()
)

# %%
ebi_link_to_umls_dict['http://www.ebi.ac.uk/efo/EFO_0000095']
# Out:
# {'C0023434', 'C0855095'}

# %% [markdown]
# #### Mappings with MRCONSO

# %%
# total unique traits

len(gwas_ebi_traits_raw_df['iri'].drop_duplicates())
# Out:
# 5717

# %%
# mrconso-compatible unique traits

len(gwas_ebi_traits_umls_subs_noncui_df['iri'].drop_duplicates())
# Out:
# 848

# %%
mrconso_st_df
# Out:
#                CUI  LAT TS        LUI STT        SUI ISPREF        AUI  \
# 0         C0000005  ENG  P   L0000005  PF   S0007492      Y  A26634265
# 1         C0000005  ENG  S   L0270109  PF   S0007491      Y  A26634266
# 10        C0000039  ENG  P   L0000039  PF  S17175117      N  A28315139
# 11        C0000039  ENG  P   L0000039  PF  S17175117      Y  A28572604
# 12        C0000039  ENG  P   L0000039  VC   S0007564      Y   A0016515
# ...            ...  ... ..        ...  ..        ...    ...        ...
# 16857339  C5574640  ENG  S  L17663434  PF  S21286067      Y  A33944162
# 16857340  C5574641  ENG  P  L17663430  PF  S21286031      Y  A33944163
# 16857341  C5574641  ENG  S  L17663429  PF  S21286030      Y  A33944560
# 16857342  C5574642  ENG  P  L17662944  PF  S21285763      Y  A33944049
# 16857343  C5574642  ENG  S  L17663471  PF  S21285761      Y  A33944164
#
#                SAUI      SCUI     SDUI     SAB  TTY     CODE  \
# 0               NaN  M0019694  D012711     MSH  PEP  D012711
# 1               NaN  M0019694  D012711     MSH   ET  D012711
# 10        9194921.0   1926948      NaN  RXNORM   IN  1926948
# 11              NaN       NaN      NaN     MTH   PN   NOCODE
# 12              NaN  M0023172  D015060     MSH   MH  D015060
# ...             ...       ...      ...     ...  ...      ...
# 16857339        NaN     Q9004      NaN   HCPCS   AB    Q9004
# 16857340        NaN     S1091      NaN   HCPCS   PT    S1091
# 16857341        NaN     S1091      NaN   HCPCS   AB    S1091
# 16857342        NaN     S9432      NaN   HCPCS   PT    S9432
# 16857343        NaN     S9432      NaN   HCPCS   AB    S9432
#
#                                                         STR  SRL SUPPRESS  \
# 0                            (131)I-Macroaggregated Albumin  NaN        N
# 1                                                (131)I-MAA  NaN        N
# 10                       1,2-dipalmitoylphosphatidylcholine  NaN        N
# 11                       1,2-dipalmitoylphosphatidylcholine  NaN        N
# 12                       1,2-Dipalmitoylphosphatidylcholine  NaN        N
# ...                                                     ...  ...      ...
# 16857339                       Va whole health partner serv  NaN        Y
# 16857340  Stent, non-coronary, temporary, with delivery ...  NaN        N
# 16857341                          Stent non-coronary propel  NaN        Y
# 16857342  Medical foods for non-inborn errors of metabolism  NaN        N
# 16857343                       Med food non inborn err meta  NaN        Y
#
#             CVF                                          sem_types
# 0         256.0  {Amino Acid, Peptide, or Protein, Indicator, R...
# 1         256.0  {Amino Acid, Peptide, or Protein, Indicator, R...
# 10        256.0        {Organic Chemical, Pharmacologic Substance}
# 11        256.0        {Organic Chemical, Pharmacologic Substance}
# 12          NaN        {Organic Chemical, Pharmacologic Substance}
# ...         ...                                                ...
# 16857339    NaN                             {Health Care Activity}
# 16857340    NaN                                   {Medical Device}
# 16857341    NaN                                   {Medical Device}
# 16857342    NaN                                             {Food}
# 16857343    NaN                                             {Food}
#
# [11855837 rows x 19 columns]

# %%
gwas_ebi_traits_umls_subs_noncui_mrconso_df = pd.merge(
    left=gwas_ebi_traits_umls_subs_noncui_df,
    right=mrconso_st_df[['CUI', 'STR', 'CODE', 'SAB']],
    left_on='ext_id',
    right_on='CODE',
    how='left'
)

# %%
gwas_ebi_traits_umls_subs_noncui_mrconso_df['SAB']
# Out:
# 0                MSH
# 1                MSH
# 2                MSH
# 3                MSH
# 4                MSH
#             ...
# 25879            MSH
# 25880            MSH
# 25881    SNOMEDCT_US
# 25882    SNOMEDCT_US
# 25883            MDR
# Name: SAB, Length: 25884, dtype: object

# %%
# enforcing that target codes come from restricted list of sources

gwas_ebi_traits_umls_subs_noncui_mrconso_df = (
    gwas_ebi_traits_umls_subs_noncui_mrconso_df[
        gwas_ebi_traits_umls_subs_noncui_mrconso_df['SAB']
            .isin(sum(umls_external_codes.values(), []))
    ]
)

# %%
gwas_ebi_traits_umls_subs_noncui_mrconso_df
# Out:
#                                         iri lang  \
# 0      http://www.ebi.ac.uk/efo/EFO_1000965   en
# 1      http://www.ebi.ac.uk/efo/EFO_1000965   en
# 2      http://www.ebi.ac.uk/efo/EFO_1000965   en
# 3      http://www.ebi.ac.uk/efo/EFO_1000965   en
# 4      http://www.ebi.ac.uk/efo/EFO_1000965   en
# ...                                     ...  ...
# 25879  http://www.ebi.ac.uk/efo/EFO_0004277   en
# 25880  http://www.ebi.ac.uk/efo/EFO_0004277   en
# 25881  http://www.ebi.ac.uk/efo/EFO_0004277   en
# 25882  http://www.ebi.ac.uk/efo/EFO_0004277   en
# 25883  http://www.ebi.ac.uk/efo/EFO_0004277   en
#
#                                              description  \
# 0      [A systemic non-thrombocytopenic purpura cause...
# 1      [A systemic non-thrombocytopenic purpura cause...
# 2      [A systemic non-thrombocytopenic purpura cause...
# 3      [A systemic non-thrombocytopenic purpura cause...
# 4      [A systemic non-thrombocytopenic purpura cause...
# ...                                                  ...
# 25879  [Tissue NECROSIS in any area of the brain, inc...
# 25880  [Tissue NECROSIS in any area of the brain, inc...
# 25881  [Tissue NECROSIS in any area of the brain, inc...
# 25882  [Tissue NECROSIS in any area of the brain, inc...
# 25883  [Tissue NECROSIS in any area of the brain, inc...
#
#                                                 synonyms  \
# 0      [Autoimmune purpura (disorder) [Ambiguous], Al...
# 1      [Autoimmune purpura (disorder) [Ambiguous], Al...
# 2      [Autoimmune purpura (disorder) [Ambiguous], Al...
# 3      [Autoimmune purpura (disorder) [Ambiguous], Al...
# 4      [Autoimmune purpura (disorder) [Ambiguous], Al...
# ...                                                  ...
# 25879  [ANTERIOR CEREBRAL CIRC INFARCT, Infarction, A...
# 25880  [ANTERIOR CEREBRAL CIRC INFARCT, Infarction, A...
# 25881  [ANTERIOR CEREBRAL CIRC INFARCT, Infarction, A...
# 25882  [ANTERIOR CEREBRAL CIRC INFARCT, Infarction, A...
# 25883  [ANTERIOR CEREBRAL CIRC INFARCT, Infarction, A...
#
#                                               annotation  \
# 0      {'database_cross_reference': ['DOID:11123', 'M...
# 1      {'database_cross_reference': ['DOID:11123', 'M...
# 2      {'database_cross_reference': ['DOID:11123', 'M...
# 3      {'database_cross_reference': ['DOID:11123', 'M...
# 4      {'database_cross_reference': ['DOID:11123', 'M...
# ...                                                  ...
# 25879  {'database_cross_reference': ['DOID:3454', 'IC...
# 25880  {'database_cross_reference': ['DOID:3454', 'IC...
# 25881  {'database_cross_reference': ['DOID:3454', 'IC...
# 25882  {'database_cross_reference': ['DOID:3454', 'IC...
# 25883  {'database_cross_reference': ['DOID:3454', 'IC...
#
#                            label ontology_name ontology_prefix  \
# 0      Henoch-Schoenlein purpura           efo             EFO
# 1      Henoch-Schoenlein purpura           efo             EFO
# 2      Henoch-Schoenlein purpura           efo             EFO
# 3      Henoch-Schoenlein purpura           efo             EFO
# 4      Henoch-Schoenlein purpura           efo             EFO
# ...                          ...           ...             ...
# 25879           brain infarction           efo             EFO
# 25880           brain infarction           efo             EFO
# 25881           brain infarction           efo             EFO
# 25882           brain infarction           efo             EFO
# 25883           brain infarction           efo             EFO
#
#                            ontology_iri  is_obsolete  ...  \
# 0      http://www.ebi.ac.uk/efo/efo.owl        False  ...
# 1      http://www.ebi.ac.uk/efo/efo.owl        False  ...
# 2      http://www.ebi.ac.uk/efo/efo.owl        False  ...
# 3      http://www.ebi.ac.uk/efo/efo.owl        False  ...
# 4      http://www.ebi.ac.uk/efo/efo.owl        False  ...
# ...                                 ...          ...  ...
# 25879  http://www.ebi.ac.uk/efo/efo.owl        False  ...
# 25880  http://www.ebi.ac.uk/efo/efo.owl        False  ...
# 25881  http://www.ebi.ac.uk/efo/efo.owl        False  ...
# 25882  http://www.ebi.ac.uk/efo/efo.owl        False  ...
# 25883  http://www.ebi.ac.uk/efo/efo.owl        False  ...
#
#                                              obo_synonym  is_preferred_root  \
# 0                                                   None              False
# 1                                                   None              False
# 2                                                   None              False
# 3                                                   None              False
# 4                                                   None              False
# ...                                                  ...                ...
# 25879  [{'name': 'brain infarction', 'scope': 'hasExa...              False
# 25880  [{'name': 'brain infarction', 'scope': 'hasExa...              False
# 25881  [{'name': 'brain infarction', 'scope': 'hasExa...              False
# 25882  [{'name': 'brain infarction', 'scope': 'hasExa...              False
# 25883  [{'name': 'brain infarction', 'scope': 'hasExa...              False
#
#                                                   _links              db_ids  \
# 0      {'self': {'href': 'https://www.ebi.ac.uk/ols/a...        MeSH:D011695
# 1      {'self': {'href': 'https://www.ebi.ac.uk/ols/a...        MeSH:D011695
# 2      {'self': {'href': 'https://www.ebi.ac.uk/ols/a...        MeSH:D011695
# 3      {'self': {'href': 'https://www.ebi.ac.uk/ols/a...        MeSH:D011695
# 4      {'self': {'href': 'https://www.ebi.ac.uk/ols/a...        MeSH:D011695
# ...                                                  ...                 ...
# 25879  {'self': {'href': 'https://www.ebi.ac.uk/ols/a...        MESH:D020520
# 25880  {'self': {'href': 'https://www.ebi.ac.uk/ols/a...        MESH:D020520
# 25881  {'self': {'href': 'https://www.ebi.ac.uk/ols/a...  SNOMEDCT:230693009
# 25882  {'self': {'href': 'https://www.ebi.ac.uk/ols/a...  SNOMEDCT:230693009
# 25883  {'self': {'href': 'https://www.ebi.ac.uk/ols/a...     MedDRA:10072154
#
#            pref     ext_id       CUI  \
# 0          MeSH    D011695  C0034152
# 1          MeSH    D011695  C0034152
# 2          MeSH    D011695  C0034152
# 3          MeSH    D011695  C0034152
# 4          MeSH    D011695  C0034152
# ...         ...        ...       ...
# 25879      MESH    D020520  C0751955
# 25880      MESH    D020520  C0751955
# 25881  SNOMEDCT  230693009  C0393953
# 25882  SNOMEDCT  230693009  C0393953
# 25883    MedDRA   10072154  C0751955
#
#                                                      STR       CODE  \
# 0                              Henoch-Schoenlein Purpura    D011695
# 1                              Purpura, Henoch-Schonlein    D011695
# 2                              Purpura, Schonlein-Henoch    D011695
# 3                               Henoch-Schonlein Purpura    D011695
# 4                              Henoch Schonlein Purpuras    D011695
# ...                                                  ...        ...
# 25879                                    Infarcts, Brain    D020520
# 25880                                     Infarct, Brain    D020520
# 25881           Anterior cerebral circulation infarction  230693009
# 25882  Anterior cerebral circulation infarction (diso...  230693009
# 25883                                   Brain infarction   10072154
#
#                SAB
# 0              MSH
# 1              MSH
# 2              MSH
# 3              MSH
# 4              MSH
# ...            ...
# 25879          MSH
# 25880          MSH
# 25881  SNOMEDCT_US
# 25882  SNOMEDCT_US
# 25883          MDR
#
# [20323 rows x 29 columns]

# %%
ebi_link_to_umls_mrconso_dict = (
    gwas_ebi_traits_umls_subs_noncui_mrconso_df
    [['iri', 'CUI']]
    .groupby('iri')
    .agg(set)
    ['CUI']
    .to_dict()
)

# %%
len(ebi_link_to_umls_mrconso_dict)
# Out:
# 848

# %% [markdown]
# #### Merging direct and indirect mappings (`iri -> {CUI}`)

# %%
len(ebi_link_to_umls_dict), len(ebi_link_to_umls_mrconso_dict)
# Out:
# (324, 848)

# %%
iri_to_cui_dict = defaultdict(set)

for iri, cuis in ebi_link_to_umls_dict.items():
    iri_to_cui_dict[iri].update(cuis)
    
for iri, cuis in ebi_link_to_umls_mrconso_dict.items():
    iri_to_cui_dict[iri].update(cuis)

# %%
len(iri_to_cui_dict)
# Out:
# 849

# %% [markdown]
# ## Mapping to gene names UMLS

# %%
gwas_short_binary_df['gene_lower'] = gwas_short_binary_df['gene'].str.lower()

# %%
gwas_gene_lowercase_list = list(
    gwas_short_binary_df['gene_lower']
        .drop_duplicates()
)
len(gwas_gene_lowercase_list)
# Out:
# 30811

# %%
pref_semtypes = {
    'Amino Acid, Peptide, or Protein',
    'Gene or Genome'
}

# %%
mrconso_st_df['STR_lower'] = mrconso_st_df['STR'].str.lower()

# %%
mrconso_gene_st_df = mrconso_st_df[
    (
          mrconso_st_df['STR_lower'].isin(gwas_gene_lowercase_list)
        & mrconso_st_df['sem_types'].apply(lambda x: pref_semtypes.intersection(x))
    )
]
len(mrconso_gene_st_df)
# Out:
# 57943

# %%
mrconso_gene_to_cui_dict = (
    mrconso_gene_st_df[['CUI', 'STR_lower']]
        .groupby('STR_lower')
        .agg(set)
        ['CUI']
        .to_dict()
)

# %%
mrconso_gene_to_cui_dict['a1cf']
# Out:
# {'C0104364', 'C2240226'}

# %% [markdown]
# ## Adding mappings to `gwas_short_binary_df`

# %%
gwas_short_binary_df['trait_cui'] = (
    gwas_short_binary_df['trait'].apply(lambda x: iri_to_cui_dict.get(x))
)

# %%
gwas_short_binary_df
# Out:
#         PUBMEDID        DATE  \
# 0       29059683  2017-10-23
# 1       29059683  2017-10-23
# 2       29059683  2017-10-23
# 4       29059683  2017-10-23
# 4       29059683  2017-10-23
# ...          ...         ...
# 552113  35120996  2022-02-01
# 552113  35120996  2022-02-01
# 552113  35120996  2022-02-01
# 552114  35120996  2022-02-01
# 552115  35120996  2022-02-01
#
#                                             DISEASE/TRAIT  \
# 0                                           Breast cancer
# 1                                           Breast cancer
# 2                                           Breast cancer
# 4                                           Breast cancer
# 4                                           Breast cancer
# ...                                                   ...
# 552113        Biliverdin levels in chronic kidney disease
# 552113        Biliverdin levels in chronic kidney disease
# 552113        Biliverdin levels in chronic kidney disease
# 552114  Dimethylguanido valerate levels in chronic kid...
# 552115           Guanine levels in chronic kidney disease
#
#                        MAPPED_TRAIT                      MAPPED_TRAIT_URI  \
# 0                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 1                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 2                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 4                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 4                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# ...                             ...                                   ...
# 552113       biliverdin measurement  http://www.ebi.ac.uk/efo/EFO_0021033
# 552113       biliverdin measurement  http://www.ebi.ac.uk/efo/EFO_0021033
# 552113       biliverdin measurement  http://www.ebi.ac.uk/efo/EFO_0021033
# 552114  carboxylic acid measurement  http://www.ebi.ac.uk/efo/EFO_0010468
# 552115          guanine measurement  http://www.ebi.ac.uk/efo/EFO_0801165
#
#        REPORTED GENE(S)                                        MAPPED_GENE  \
# 0                    NR                                              FGF10
# 1                    NR                                            KREMEN1
# 2                    NR                                              TRPS1
# 4                    NR                                 PPP4R3A - CATSPERB
# 4                    NR                                 PPP4R3A - CATSPERB
# ...                 ...                                                ...
# 552113              NaN  UGT1A9, UGT1A5, UGT1A10, UGT1A6, UGT1A7, UGT1A...
# 552113              NaN  UGT1A9, UGT1A5, UGT1A10, UGT1A6, UGT1A7, UGT1A...
# 552113              NaN  UGT1A9, UGT1A5, UGT1A10, UGT1A6, UGT1A7, UGT1A...
# 552114              NaN                                              AGXT2
# 552115              NaN                                             PHYHD1
#
#             gene                                 trait  \
# 0          FGF10  http://www.ebi.ac.uk/efo/EFO_0000305
# 1        KREMEN1  http://www.ebi.ac.uk/efo/EFO_0000305
# 2          TRPS1  http://www.ebi.ac.uk/efo/EFO_0000305
# 4        PPP4R3A  http://www.ebi.ac.uk/efo/EFO_0000305
# 4       CATSPERB  http://www.ebi.ac.uk/efo/EFO_0000305
# ...          ...                                   ...
# 552113    UGT1A8  http://www.ebi.ac.uk/efo/EFO_0021033
# 552113    UGT1A4  http://www.ebi.ac.uk/efo/EFO_0021033
# 552113    UGT1A3  http://www.ebi.ac.uk/efo/EFO_0021033
# 552114     AGXT2  http://www.ebi.ac.uk/efo/EFO_0010468
# 552115    PHYHD1  http://www.ebi.ac.uk/efo/EFO_0801165
#
#                                                 trait_cui gene_lower
# 0       {C0678222, C0346153, C0006142, C3809918, C1861...      fgf10
# 1       {C0678222, C0346153, C0006142, C3809918, C1861...    kremen1
# 2       {C0678222, C0346153, C0006142, C3809918, C1861...      trps1
# 4       {C0678222, C0346153, C0006142, C3809918, C1861...    ppp4r3a
# 4       {C0678222, C0346153, C0006142, C3809918, C1861...   catsperb
# ...                                                   ...        ...
# 552113                                               None     ugt1a8
# 552113                                               None     ugt1a4
# 552113                                               None     ugt1a3
# 552114                                               None      agxt2
# 552115                                               None     phyhd1
#
# [837286 rows x 11 columns]

# %%
gwas_short_binary_df['gene_cui'] = (
    gwas_short_binary_df['gene_lower'].apply(lambda x: mrconso_gene_to_cui_dict.get(x))
)

# %%
gwas_short_binary_df
# Out:
#         PUBMEDID        DATE  \
# 0       29059683  2017-10-23
# 1       29059683  2017-10-23
# 2       29059683  2017-10-23
# 4       29059683  2017-10-23
# 4       29059683  2017-10-23
# ...          ...         ...
# 552113  35120996  2022-02-01
# 552113  35120996  2022-02-01
# 552113  35120996  2022-02-01
# 552114  35120996  2022-02-01
# 552115  35120996  2022-02-01
#
#                                             DISEASE/TRAIT  \
# 0                                           Breast cancer
# 1                                           Breast cancer
# 2                                           Breast cancer
# 4                                           Breast cancer
# 4                                           Breast cancer
# ...                                                   ...
# 552113        Biliverdin levels in chronic kidney disease
# 552113        Biliverdin levels in chronic kidney disease
# 552113        Biliverdin levels in chronic kidney disease
# 552114  Dimethylguanido valerate levels in chronic kid...
# 552115           Guanine levels in chronic kidney disease
#
#                        MAPPED_TRAIT                      MAPPED_TRAIT_URI  \
# 0                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 1                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 2                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 4                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 4                  breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# ...                             ...                                   ...
# 552113       biliverdin measurement  http://www.ebi.ac.uk/efo/EFO_0021033
# 552113       biliverdin measurement  http://www.ebi.ac.uk/efo/EFO_0021033
# 552113       biliverdin measurement  http://www.ebi.ac.uk/efo/EFO_0021033
# 552114  carboxylic acid measurement  http://www.ebi.ac.uk/efo/EFO_0010468
# 552115          guanine measurement  http://www.ebi.ac.uk/efo/EFO_0801165
#
#        REPORTED GENE(S)                                        MAPPED_GENE  \
# 0                    NR                                              FGF10
# 1                    NR                                            KREMEN1
# 2                    NR                                              TRPS1
# 4                    NR                                 PPP4R3A - CATSPERB
# 4                    NR                                 PPP4R3A - CATSPERB
# ...                 ...                                                ...
# 552113              NaN  UGT1A9, UGT1A5, UGT1A10, UGT1A6, UGT1A7, UGT1A...
# 552113              NaN  UGT1A9, UGT1A5, UGT1A10, UGT1A6, UGT1A7, UGT1A...
# 552113              NaN  UGT1A9, UGT1A5, UGT1A10, UGT1A6, UGT1A7, UGT1A...
# 552114              NaN                                              AGXT2
# 552115              NaN                                             PHYHD1
#
#             gene                                 trait  \
# 0          FGF10  http://www.ebi.ac.uk/efo/EFO_0000305
# 1        KREMEN1  http://www.ebi.ac.uk/efo/EFO_0000305
# 2          TRPS1  http://www.ebi.ac.uk/efo/EFO_0000305
# 4        PPP4R3A  http://www.ebi.ac.uk/efo/EFO_0000305
# 4       CATSPERB  http://www.ebi.ac.uk/efo/EFO_0000305
# ...          ...                                   ...
# 552113    UGT1A8  http://www.ebi.ac.uk/efo/EFO_0021033
# 552113    UGT1A4  http://www.ebi.ac.uk/efo/EFO_0021033
# 552113    UGT1A3  http://www.ebi.ac.uk/efo/EFO_0021033
# 552114     AGXT2  http://www.ebi.ac.uk/efo/EFO_0010468
# 552115    PHYHD1  http://www.ebi.ac.uk/efo/EFO_0801165
#
#                                                 trait_cui gene_lower  \
# 0       {C0678222, C0346153, C0006142, C3809918, C1861...      fgf10
# 1       {C0678222, C0346153, C0006142, C3809918, C1861...    kremen1
# 2       {C0678222, C0346153, C0006142, C3809918, C1861...      trps1
# 4       {C0678222, C0346153, C0006142, C3809918, C1861...    ppp4r3a
# 4       {C0678222, C0346153, C0006142, C3809918, C1861...   catsperb
# ...                                                   ...        ...
# 552113                                               None     ugt1a8
# 552113                                               None     ugt1a4
# 552113                                               None     ugt1a3
# 552114                                               None      agxt2
# 552115                                               None     phyhd1
#
#                     gene_cui
# 0       {C1432620, C1333535}
# 1                 {C1424993}
# 2                 {C1421175}
# 4                 {C1822785}
# 4                 {C1426973}
# ...                      ...
# 552113  {C1122343, C1421332}
# 552113            {C1421328}
# 552113            {C1421327}
# 552114            {C1422631}
# 552115            {C1428070}
#
# [837286 rows x 12 columns]

# %%
gwas_short_binary_cui_df = (
    gwas_short_binary_df
        .explode('gene_cui')
        .explode('trait_cui')
        .dropna(subset=['trait_cui', 'gene_cui'])
)

# %%
gwas_short_binary_cui_df
# Out:
#         PUBMEDID        DATE                               DISEASE/TRAIT  \
# 0       29059683  2017-10-23                               Breast cancer
# 0       29059683  2017-10-23                               Breast cancer
# 0       29059683  2017-10-23                               Breast cancer
# 0       29059683  2017-10-23                               Breast cancer
# 0       29059683  2017-10-23                               Breast cancer
# ...          ...         ...                                         ...
# 552112  35120996  2022-02-01  Bilirubin levels in chronic kidney disease
# 552112  35120996  2022-02-01  Bilirubin levels in chronic kidney disease
# 552112  35120996  2022-02-01  Bilirubin levels in chronic kidney disease
# 552112  35120996  2022-02-01  Bilirubin levels in chronic kidney disease
# 552112  35120996  2022-02-01  Bilirubin levels in chronic kidney disease
#
#                  MAPPED_TRAIT                      MAPPED_TRAIT_URI  \
# 0            breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 0            breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 0            breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 0            breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# 0            breast carcinoma  http://www.ebi.ac.uk/efo/EFO_0000305
# ...                       ...                                   ...
# 552112  bilirubin measurement  http://www.ebi.ac.uk/efo/EFO_0004570
# 552112  bilirubin measurement  http://www.ebi.ac.uk/efo/EFO_0004570
# 552112  bilirubin measurement  http://www.ebi.ac.uk/efo/EFO_0004570
# 552112  bilirubin measurement  http://www.ebi.ac.uk/efo/EFO_0004570
# 552112  bilirubin measurement  http://www.ebi.ac.uk/efo/EFO_0004570
#
#        REPORTED GENE(S)                              MAPPED_GENE     gene  \
# 0                    NR                                    FGF10    FGF10
# 0                    NR                                    FGF10    FGF10
# 0                    NR                                    FGF10    FGF10
# 0                    NR                                    FGF10    FGF10
# 0                    NR                                    FGF10    FGF10
# ...                 ...                                      ...      ...
# 552112              NaN  UGT1A9, UGT1A7, UGT1A10, UGT1A8, UGT1A6  UGT1A10
# 552112              NaN  UGT1A9, UGT1A7, UGT1A10, UGT1A8, UGT1A6  UGT1A10
# 552112              NaN  UGT1A9, UGT1A7, UGT1A10, UGT1A8, UGT1A6   UGT1A8
# 552112              NaN  UGT1A9, UGT1A7, UGT1A10, UGT1A8, UGT1A6   UGT1A8
# 552112              NaN  UGT1A9, UGT1A7, UGT1A10, UGT1A8, UGT1A6   UGT1A6
#
#                                        trait trait_cui gene_lower  gene_cui
# 0       http://www.ebi.ac.uk/efo/EFO_0000305  C0678222      fgf10  C1432620
# 0       http://www.ebi.ac.uk/efo/EFO_0000305  C0346153      fgf10  C1432620
# 0       http://www.ebi.ac.uk/efo/EFO_0000305  C0006142      fgf10  C1432620
# 0       http://www.ebi.ac.uk/efo/EFO_0000305  C3809918      fgf10  C1432620
# 0       http://www.ebi.ac.uk/efo/EFO_0000305  C1861906      fgf10  C1432620
# ...                                      ...       ...        ...       ...
# 552112  http://www.ebi.ac.uk/efo/EFO_0004570  C0344395    ugt1a10  C1311129
# 552112  http://www.ebi.ac.uk/efo/EFO_0004570  C0344395    ugt1a10  C1421323
# 552112  http://www.ebi.ac.uk/efo/EFO_0004570  C0344395     ugt1a8  C1122343
# 552112  http://www.ebi.ac.uk/efo/EFO_0004570  C0344395     ugt1a8  C1421332
# 552112  http://www.ebi.ac.uk/efo/EFO_0004570  C0344395     ugt1a6  C1421330
#
# [1639208 rows x 12 columns]

# %% [markdown]
# ## Extracting pairs and saving

# %%
gwas_pairs = list({
    tuple(sorted(p)) for p in list(
        zip(
            gwas_short_binary_cui_df['trait_cui'],
            gwas_short_binary_cui_df['gene_cui']
        )
    )
})
len(gwas_pairs)
# Out:
# 642544

# %%
with open('../../benchmark_data/01_cui_pairs_json/gwas_cui_pairs.json', 'w') as f:
    json.dump(gwas_pairs, f)
