# %% [markdown]
# # Drugcentral data collection

# %% [markdown]
# Prerequisites:
# - (SQL) postgres dump: https://unmtid-shinyapps.net/download/drugcentral.dump.08222022.sql.gz
# - (SQL) Run sql server: `postgres -D ~/software/postgresql/data`
# - (SQL) Check if it works with postgres CLI: `psql -h /tmp/ -d drugcentral_102422`
# - (TSV) file: https://unmtid-shinyapps.net/download/DrugCentral/2021_09_01/drug.target.interaction.tsv.gz

# %%
# !wget https://unmtid-shinyapps.net/download/DrugCentral/2021_09_01/drug.target.interaction.tsv.gz --no-check-certificate

# %%
import psycopg2
import pandas as pd

from tqdm import tqdm
import time
import json

import numpy as np

from collections import Counter, defaultdict

# %% [markdown]
# ## Opening ready-to-use files

# %% [markdown]
# ### Exported `.tsv` table

# %%
drugcentral_export_df = pd.read_table('drug.target.interaction.tsv.gz')
len(drugcentral_export_df)
# Out:
# 19378

# %%
drugcentral_export_df
# Out:
#              DRUG_NAME  STRUCT_ID  \
# 0      levobupivacaine          4
# 1      levobupivacaine          4
# 2      levobupivacaine          4
# 3      levobupivacaine          4
# 4      levobupivacaine          4
# ...                ...        ...
# 19373      samidorphan       5460
# 19374        sotorasib       5461
# 19375    ibrexafungerp       5462
# 19376    ibrexafungerp       5462
# 19377    ibrexafungerp       5462
#
#                                              TARGET_NAME TARGET_CLASS  \
# 0      Potassium voltage-gated channel subfamily H me...  Ion channel
# 1            Sodium channel protein type 1 subunit alpha  Ion channel
# 2            Sodium channel protein type 4 subunit alpha  Ion channel
# 3                  Prostaglandin E2 receptor EP1 subtype         GPCR
# 4                                    Cytochrome P450 2D6       Enzyme
# ...                                                  ...          ...
# 19373                         Delta-type opioid receptor         GPCR
# 19374                                        GTPase KRas       Enzyme
# 19375       Beta-1,3-glucan synthase catalytic subunit 1       Enzyme
# 19376          1,3-Beta-D-glucan-UDP glucosyltransferase       Enzyme
# 19377          1,3-Beta-D-glucan-UDP glucosyltransferase       Enzyme
#
#       ACCESSION    GENE     SWISSPROT  ACT_VALUE  ACT_UNIT ACT_TYPE  \
# 0        Q12809   KCNH2   KCNH2_HUMAN      4.890       NaN     IC50
# 1        P35498   SCN1A   SCN1A_HUMAN      5.790       NaN     IC50
# 2        P35499   SCN4A   SCN4A_HUMAN        NaN       NaN      NaN
# 3        P34995  PTGER1   PE2R1_HUMAN        NaN       NaN      NaN
# 4        P10635  CYP2D6   CP2D6_HUMAN      6.707       NaN     IC50
# ...         ...     ...           ...        ...       ...      ...
# 19373    P41143   OPRD1    OPRD_HUMAN      8.590       NaN       Ki
# 19374    P01116    KRAS    RASK_HUMAN      7.030       NaN     IC50
# 19375    O13428    GSC1  O13428_CANAX      8.350       NaN     IC50
# 19376    Q6FTN8    FKS1  Q6FTN8_CANGA      7.830       NaN     IC50
# 19377    P87204     FKS  P87204_ASPFM      8.970       NaN     IC50
#
#                                              ACT_COMMENT  \
# 0      Inhibition of wild-type human ERG channel expr...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4      DRUGMATRIX: CYP450, 2D6 enzyme inhibition (sub...
# ...                                                  ...
# 19373                                                NaN
# 19374                                 KRAS G12C mutation
# 19375  MoA - inhibits the biosynthesis of beta-(1,3)-...
# 19376  MoA - inhibits the biosynthesis of beta-(1,3)-...
# 19377  MoA - inhibits the biosynthesis of beta-(1,3)-...
#
#                   ACT_SOURCE RELATION  MOA             MOA_SOURCE  \
# 0                     CHEMBL        =  NaN                    NaN
# 1                  WOMBAT-PK        =  NaN                    NaN
# 2                  WOMBAT-PK      NaN  1.0                 CHEMBL
# 3                  WOMBAT-PK      NaN  NaN                    NaN
# 4                DRUG MATRIX        =  NaN                    NaN
# ...                      ...      ...  ...                    ...
# 19373             DRUG LABEL        =  NaN                    NaN
# 19374             DRUG LABEL        =  1.0             DRUG LABEL
# 19375  SCIENTIFIC LITERATURE        =  1.0             DRUG LABEL
# 19376  SCIENTIFIC LITERATURE        =  1.0  SCIENTIFIC LITERATURE
# 19377  SCIENTIFIC LITERATURE        =  1.0  SCIENTIFIC LITERATURE
#
#                                           ACT_SOURCE_URL  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 19373  https://www.accessdata.fda.gov/drugsatfda_docs...
# 19374  https://www.accessdata.fda.gov/drugsatfda_docs...
# 19375           https://pubmed.ncbi.nlm.nih.gov/24323472
# 19376           https://pubmed.ncbi.nlm.nih.gov/24323472
# 19377           https://pubmed.ncbi.nlm.nih.gov/24323472
#
#                                           MOA_SOURCE_URL      ACTION_TYPE  \
# 0                                                    NaN              NaN
# 1                                                    NaN              NaN
# 2      https://www.ebi.ac.uk/chembl/compound/inspect/...          BLOCKER
# 3                                                    NaN              NaN
# 4                                                    NaN              NaN
# ...                                                  ...              ...
# 19373                                                NaN  PARTIAL AGONIST
# 19374  https://www.accessdata.fda.gov/drugsatfda_docs...        INHIBITOR
# 19375  https://www.accessdata.fda.gov/drugsatfda_docs...        INHIBITOR
# 19376  https://www.accessdata.fda.gov/drugsatfda_docs...        INHIBITOR
# 19377  https://www.accessdata.fda.gov/drugsatfda_docs...        INHIBITOR
#
#          TDL              ORGANISM
# 0      Tclin          Homo sapiens
# 1      Tclin          Homo sapiens
# 2      Tclin          Homo sapiens
# 3      Tclin          Homo sapiens
# 4      Tclin          Homo sapiens
# ...      ...                   ...
# 19373  Tclin          Homo sapiens
# 19374  Tchem          Homo sapiens
# 19375    NaN      Candida albicans
# 19376    NaN      Candida glabrata
# 19377    NaN  Neosartorya fumigata
#
# [19378 rows x 20 columns]

# %%
drugcentral_export_df = drugcentral_export_df[
    [
        'DRUG_NAME', 
        'STRUCT_ID', 
        'TARGET_NAME', 
        'TARGET_CLASS',
        'ACCESSION',
        'GENE',
        'ACT_SOURCE'
    ]
].dropna()

drugcentral_export_df['GENE'] = (
    drugcentral_export_df['GENE']
        .apply(lambda x: set(x.split('|')))
)
drugcentral_export_df = drugcentral_export_df.explode('GENE')

# %%
drugcentral_export_df
# Out:
#              DRUG_NAME  STRUCT_ID  \
# 0      levobupivacaine          4
# 1      levobupivacaine          4
# 2      levobupivacaine          4
# 3      levobupivacaine          4
# 4      levobupivacaine          4
# ...                ...        ...
# 19373      samidorphan       5460
# 19374        sotorasib       5461
# 19375    ibrexafungerp       5462
# 19376    ibrexafungerp       5462
# 19377    ibrexafungerp       5462
#
#                                              TARGET_NAME TARGET_CLASS  \
# 0      Potassium voltage-gated channel subfamily H me...  Ion channel
# 1            Sodium channel protein type 1 subunit alpha  Ion channel
# 2            Sodium channel protein type 4 subunit alpha  Ion channel
# 3                  Prostaglandin E2 receptor EP1 subtype         GPCR
# 4                                    Cytochrome P450 2D6       Enzyme
# ...                                                  ...          ...
# 19373                         Delta-type opioid receptor         GPCR
# 19374                                        GTPase KRas       Enzyme
# 19375       Beta-1,3-glucan synthase catalytic subunit 1       Enzyme
# 19376          1,3-Beta-D-glucan-UDP glucosyltransferase       Enzyme
# 19377          1,3-Beta-D-glucan-UDP glucosyltransferase       Enzyme
#
#       ACCESSION    GENE             ACT_SOURCE
# 0        Q12809   KCNH2                 CHEMBL
# 1        P35498   SCN1A              WOMBAT-PK
# 2        P35499   SCN4A              WOMBAT-PK
# 3        P34995  PTGER1              WOMBAT-PK
# 4        P10635  CYP2D6            DRUG MATRIX
# ...         ...     ...                    ...
# 19373    P41143   OPRD1             DRUG LABEL
# 19374    P01116    KRAS             DRUG LABEL
# 19375    O13428    GSC1  SCIENTIFIC LITERATURE
# 19376    Q6FTN8    FKS1  SCIENTIFIC LITERATURE
# 19377    P87204     FKS  SCIENTIFIC LITERATURE
#
# [22611 rows x 7 columns]

# %% [markdown]
# ### UMLS MRCONSO mapping

# %%
mrconso_path = (
    '../../UMLS_Metathesaurus/mrconso_and_semtypes_2022AA_df.pkl'
)

# %%
mrconso_st_df = pd.read_pickle(mrconso_path)

# %%
mrconso_st_df
# Out:
#                CUI  LAT TS        LUI STT        SUI ISPREF        AUI  \
# 0         C0000005  ENG  P   L0000005  PF   S0007492      Y  A26634265
# 1         C0000005  ENG  S   L0270109  PF   S0007491      Y  A26634266
# 10        C0000039  ENG  P   L0000039  PF  S17175117      N  A28315139
# 11        C0000039  ENG  P   L0000039  PF  S17175117      Y  A28572604
# 12        C0000039  ENG  P   L0000039  VC   S0007564      Y   A0016515
# ...            ...  ... ..        ...  ..        ...    ...        ...
# 16857339  C5574640  ENG  S  L17663434  PF  S21286067      Y  A33944162
# 16857340  C5574641  ENG  P  L17663430  PF  S21286031      Y  A33944163
# 16857341  C5574641  ENG  S  L17663429  PF  S21286030      Y  A33944560
# 16857342  C5574642  ENG  P  L17662944  PF  S21285763      Y  A33944049
# 16857343  C5574642  ENG  S  L17663471  PF  S21285761      Y  A33944164
#
#                SAUI      SCUI     SDUI     SAB  TTY     CODE  \
# 0               NaN  M0019694  D012711     MSH  PEP  D012711
# 1               NaN  M0019694  D012711     MSH   ET  D012711
# 10        9194921.0   1926948      NaN  RXNORM   IN  1926948
# 11              NaN       NaN      NaN     MTH   PN   NOCODE
# 12              NaN  M0023172  D015060     MSH   MH  D015060
# ...             ...       ...      ...     ...  ...      ...
# 16857339        NaN     Q9004      NaN   HCPCS   AB    Q9004
# 16857340        NaN     S1091      NaN   HCPCS   PT    S1091
# 16857341        NaN     S1091      NaN   HCPCS   AB    S1091
# 16857342        NaN     S9432      NaN   HCPCS   PT    S9432
# 16857343        NaN     S9432      NaN   HCPCS   AB    S9432
#
#                                                         STR  SRL SUPPRESS  \
# 0                            (131)I-Macroaggregated Albumin  NaN        N
# 1                                                (131)I-MAA  NaN        N
# 10                       1,2-dipalmitoylphosphatidylcholine  NaN        N
# 11                       1,2-dipalmitoylphosphatidylcholine  NaN        N
# 12                       1,2-Dipalmitoylphosphatidylcholine  NaN        N
# ...                                                     ...  ...      ...
# 16857339                       Va whole health partner serv  NaN        Y
# 16857340  Stent, non-coronary, temporary, with delivery ...  NaN        N
# 16857341                          Stent non-coronary propel  NaN        Y
# 16857342  Medical foods for non-inborn errors of metabolism  NaN        N
# 16857343                       Med food non inborn err meta  NaN        Y
#
#             CVF                                          sem_types
# 0         256.0  {Pharmacologic Substance, Indicator, Reagent, ...
# 1         256.0  {Pharmacologic Substance, Indicator, Reagent, ...
# 10        256.0        {Organic Chemical, Pharmacologic Substance}
# 11        256.0        {Organic Chemical, Pharmacologic Substance}
# 12          NaN        {Organic Chemical, Pharmacologic Substance}
# ...         ...                                                ...
# 16857339    NaN                             {Health Care Activity}
# 16857340    NaN                                   {Medical Device}
# 16857341    NaN                                   {Medical Device}
# 16857342    NaN                                             {Food}
# 16857343    NaN                                             {Food}
#
# [11855837 rows x 19 columns]

# %%
mesh_to_umls_dict = (
    mrconso_st_df[
        mrconso_st_df['SAB'] == 'MSH'
    ]
    [['CUI', 'CODE']]
        .groupby('CODE')
        .agg(set)['CUI']
        .to_dict()
)

# %% [markdown]
# ### UMLS CAS mapping

# %%
cas_to_cui_dict = pd.read_pickle(
    '../../pubchem_mappings/pc_cas_to_CUI_full_dict.pkl'
)

# %%
len(cas_to_cui_dict)
# Out:
# 132597

# %%
cas_to_cui_dict['56124-62-0']
# Out:
# {'C0068314'}

# %%
cas_to_cui_dict = pd.read_pickle(
    '../../chemidplus_obsolete/cas_to_cui_meshdb_dict.pkl'
)

# %%
len(cas_to_cui_dict)
# Out:
# 80344

# %% [markdown]
# ## SQL interface for tables

# %%
# Connection parameters, yours will be different
param_dic = {
    "host"      : "localhost",
    "database"  : "drugcentral_102422",
    "user"      : "tyagin",
}

# %%
def connect(params_dic):
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # connect to the PostgreSQL server
        print('Connecting to the PostgreSQL database...')
        conn = psycopg2.connect(**params_dic)
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        sys.exit(1) 
    print("Connection successful")
    return conn

# %%
def postgresql_to_dataframe(conn, select_query, ):
    """
    Tranform a SELECT query into a pandas dataframe
    """
    cursor = conn.cursor()
    try:
        cursor.execute(select_query)
    except (Exception, psycopg2.DatabaseError) as error:
        print("Error: %s" % error)
        cursor.close()
        return 1
    
    # Naturally we get a list of tupples
    tupples = cursor.fetchall()
    cursor.close()
    
    # We just need to turn it into a pandas dataframe
    df = pd.DataFrame(tupples)
    return df

# %%
conn = connect(param_dic)
# Out:
# Connecting to the PostgreSQL database...
# Connection successful

# %%
conn.set_client_encoding('UTF8')

# %% [markdown]
# ### getting table names

# %%
tables_cols_df = postgresql_to_dataframe(
    conn,
    """SELECT *
      FROM information_schema.columns
      WHERE table_schema = 'public' 
      order by ordinal_position;
    """
)

# %%
tables_cols_agg_df = tables_cols_df[[2,3]].groupby(2).agg(list)

# %%
tables_cols_agg_df
# Out:
#                                                                    3
# 2
# act_table_full     [act_id, struct_id, target_id, target_name, ta...
# action_type              [id, action_type, description, parent_type]
# active_ingredient  [id, active_moiety_unii, active_moiety_name, u...
# approval           [id, struct_id, approval, type, applicant, orp...
# approval_type                                            [id, descr]
# ...                                                              ...
# vetomop            [omopid, struct_id, species, relationship_type...
# vetprod            [prodid, appl_type, appl_no, trade_name, appli...
# vetprod2struct                                   [prodid, struct_id]
# vetprod_type                            [id, appl_type, description]
# vettype                                               [prodid, type]
#
# [71 rows x 1 columns]

# %%
tables_cols_dict = tables_cols_agg_df[3].to_dict()

# %% [markdown]
# ### querying ALL tables

# %%
def Query_table(table_name, limit=0):
    
    if limit:
        sql_query = f"""
            SELECT * from {table_name} limit {limit};
        """
    else:
        sql_query = f"""
            SELECT * from {table_name};
        """
    
    sql_df = postgresql_to_dataframe(
        conn,
        sql_query
    )
        
    sql_df = (
        sql_df.rename(columns=dict(enumerate(tables_cols_dict[table_name])))
    )
    
    return sql_df

# %%
tables_dict = dict()
for tname in tqdm(tables_cols_dict):
    if tname[0] != '_':
        tables_dict[tname] = Query_table(tname, limit=None)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 71/71 [00:56<00:00,  1.26it/s]

# %% [markdown]
# ### Extracting and merging specific tables

# %% [markdown]
# #### Indications table (`indications_df`: `Drug CAS -> Disease`)

# %%
indications_df = pd.merge(
    tables_dict['omop_relationship_doid_view'],
    tables_dict['structures'][['id', 'name', 'cas_reg_no']],
    left_on='struct_id',
    right_on='id',
    how='inner'
)

# %%
indications_df
# Out:
#          id_x  struct_id  concept_id relationship_name  \
# 0      144492        564    21000286        indication
# 1      146703        564    21001035        indication
# 2      143317        564    21013411     off-label use
# 3      144496        564    21000101        indication
# 4      151436        564    21000110        indication
# ...       ...        ...         ...               ...
# 41815  172341       2316    21003003        indication
# 41816  172342       2316    21003002        indication
# 41817  134154       2959    21000623        indication
# 41818  174027       5392    40249397        indication
# 41819  151427       3290    21003116  contraindication
#
#                                   concept_name  umls_cui  \
# 0                        Gonococcal meningitis  C0153225
# 1                     Streptococcal meningitis  C0154639
# 2                    Pyrexia of unknown origin  C0015970
# 3           Septicemia due to Escherichia coli  C0276088
# 4                         Bacterial septicemia  C0684256
# ...                                        ...       ...
# 41815  Diagnostic Test for Thyroid Dysfunction      None
# 41816               Pituitary Function Studies      None
# 41817       Partial Central Diabetes Insipidus      None
# 41818    Metastatic non-small cell lung cancer  C0278987
# 41819        Sensation Disturbance of Genitals      None
#
#                             snomed_full_name cui_semantic_type  \
# 0                      Gonococcal meningitis              T047
# 1                   Streptococcal meningitis              T047
# 2                  Pyrexia of unknown origin              T184
# 3         Septicemia due to Escherichia coli              T047
# 4                       Bacterial septicemia              T047
# ...                                      ...               ...
# 41815                                   None              None
# 41816                                   None              None
# 41817                                   None              None
# 41818  Metastatic non-small cell lung cancer              T191
# 41819                                   None              None
#
#        snomed_conceptid          doid  id_y          name    cas_reg_no
# 0              151004.0          None   564   ceftriaxone    73384-59-5
# 1             4510004.0    DOID:11574   564   ceftriaxone    73384-59-5
# 2             7520000.0          None   564   ceftriaxone    73384-59-5
# 3             9323009.0          None   564   ceftriaxone    73384-59-5
# 4            10001005.0  DOID:0040085   564   ceftriaxone    73384-59-5
# ...                 ...           ...   ...           ...           ...
# 41815               NaN          None  2316    protirelin    24305-27-9
# 41816               NaN          None  2316    protirelin    24305-27-9
# 41817               NaN          None  2959     lypressin       50-57-7
# 41818               NaN          None  5392    capmatinib  1029712-80-8
# 41819               NaN          None  3290  oxyquinoline      148-24-3
#
# [41820 rows x 13 columns]

# %% [markdown]
# #### Artificially created connections between targets (`drugcentral_export_df`) and drugs (`indications_df`)

# %%
drug_target_artificial_df = pd.merge(
    indications_df[['snomed_full_name', 'umls_cui', 'struct_id', 'name', 'cas_reg_no']],
    drugcentral_export_df[['DRUG_NAME', 'STRUCT_ID', 'TARGET_NAME', 'GENE']],
    left_on='struct_id',
    right_on='STRUCT_ID',
    how='inner'
).dropna()

len(drug_target_artificial_df)
# Out:
# 406142

# %%
drug_target_artificial_df
# Out:
#                                          snomed_full_name  umls_cui  \
# 0                                   Gonococcal meningitis  C0153225
# 1                                   Gonococcal meningitis  C0153225
# 2                                   Gonococcal meningitis  C0153225
# 3                                   Gonococcal meningitis  C0153225
# 4                                   Gonococcal meningitis  C0153225
# ...                                                   ...       ...
# 445676                    Metastatic urothelial carcinoma  C4288754
# 445677                    Metastatic urothelial carcinoma  C4288754
# 445678  Metastatic human epidermal growth factor 2 pos...  C4721209
# 445679  Metastatic human epidermal growth factor 2 pos...  C4721209
# 445761              Metastatic non-small cell lung cancer  C0278987
#
#         struct_id                name    cas_reg_no           DRUG_NAME  \
# 0             564         ceftriaxone    73384-59-5         ceftriaxone
# 1             564         ceftriaxone    73384-59-5         ceftriaxone
# 2             564         ceftriaxone    73384-59-5         ceftriaxone
# 3             564         ceftriaxone    73384-59-5         ceftriaxone
# 4             564         ceftriaxone    73384-59-5         ceftriaxone
# ...           ...                 ...           ...                 ...
# 445676       5366  enfortumab vedotin  1346452-25-2  enfortumab vedotin
# 445677       5366  enfortumab vedotin  1346452-25-2  enfortumab vedotin
# 445678       5434        margetuximab  1350624-75-7        margetuximab
# 445679       5434        margetuximab  1350624-75-7        margetuximab
# 445761       5392          capmatinib  1029712-80-8          capmatinib
#
#         STRUCT_ID                                        TARGET_NAME     GENE
# 0             564                        Peptidoglycan synthase FtsI     ftsI
# 1             564                      Penicillin-binding protein 1A     mrcA
# 2             564                      Penicillin-binding protein 1B     mrcB
# 3             564                       Penicillin-binding protein 2     mrdA
# 4             564                               D-amino-acid oxidase      DAO
# ...           ...                                                ...      ...
# 445676       5366                                       Tubulin beta    TUBB3
# 445677       5366                                           Nectin-4  NECTIN4
# 445678       5434            Receptor tyrosine-protein kinase erbB-2    ERBB2
# 445679       5434  Low affinity immunoglobulin gamma Fc region re...   FCGR3A
# 445761       5392                  Hepatocyte growth factor receptor      MET
#
# [406142 rows x 9 columns]

# %% [markdown]
# #### Pharma class (`pharm_action_df`: `Drug CAS -> MeSH indication`)

# %%
pharm_action_df = pd.merge(
    tables_dict['pharma_class'],
    tables_dict['structures'][['id', 'name', 'cas_reg_no']],
    left_on='struct_id',
    right_on='id',
    #how='inner'
)

# %%
pharm_action_df
# Out:
#          id_x  struct_id type                                   name_x  \
# 0      449782       3024   PA                               Analgesics
# 1      449783       3024   PA                 Analgesics, Non-Narcotic
# 2      449784       3024   PA                 Anti-Inflammatory Agents
# 3      449785       3024   PA  Anti-Inflammatory Agents, Non-Steroidal
# 4      449786       3024   PA                     Antirheumatic Agents
# ...       ...        ...  ...                                      ...
# 25342  463923       4867   PA                        Enzyme Inhibitors
# 25343  463925       4867   PA                  Gastrointestinal Agents
# 25344  463927       4867   PA                   Proton Pump Inhibitors
# 25345  463931       1604   PA                   Anti-Arrhythmia Agents
# 25346  463932       1604   PA                    Cardiovascular Agents
#
#       class_code source  id_y          name_y   cas_reg_no
# 0        D000700   MeSH  3024        bevonium   33371-53-8
# 1        D018712   MeSH  3024        bevonium   33371-53-8
# 2        D000893   MeSH  3024        bevonium   33371-53-8
# 3        D000894   MeSH  3024        bevonium   33371-53-8
# 4        D018501   MeSH  3024        bevonium   33371-53-8
# ...          ...    ...   ...             ...          ...
# 25342    D004791   MeSH  4867  dexrabeprazole  177795-60-7
# 25343    D005765   MeSH  4867  dexrabeprazole  177795-60-7
# 25344    D054328   MeSH  4867  dexrabeprazole  177795-60-7
# 25345    D000889   MeSH  1604       lorajmine   47562-08-3
# 25346    D002317   MeSH  1604       lorajmine   47562-08-3
#
# [25347 rows x 9 columns]

# %% [markdown]
# #### Adverse effects (`faers`): (`adverse_eff_meddra_cui_df`: `Drug CAS -> MedDRA adv effect`)

# %%
adverse_eff_df = pd.merge(
    tables_dict['faers'][['struct_id', 'meddra_name', 'meddra_code']],
    tables_dict['structures'][['id', 'name', 'cas_reg_no']],
    left_on='struct_id',
    right_on='id',
    how='inner'
)

# %%
adverse_eff_df
# Out:
#         struct_id                         meddra_name  meddra_code    id  \
# 0            4185                Abdominal discomfort     10000059  4185
# 1            4185                                Acne     10000496  4185
# 2            4185                         Acrochordon     10000591  4185
# 3            4185                   Actinic keratosis     10000614  4185
# 4            4185                            Alopecia     10001760  4185
# ...           ...                                 ...          ...   ...
# 310049       4714         Metaphyseal corner fracture     10079667  4714
# 310050       2063  Negative pressure pulmonary oedema     10080589  2063
# 310051       5324        Product administration error     10081576  5324
# 310052       1574         Product dose omission issue     10084406  1574
# 310053       4387                   SARS-CoV-2 sepsis     10084639  4387
#
#                        name   cas_reg_no
# 0               vemurafenib  918504-65-1
# 1               vemurafenib  918504-65-1
# 2               vemurafenib  918504-65-1
# 3               vemurafenib  918504-65-1
# 4               vemurafenib  918504-65-1
# ...                     ...          ...
# 310049   strontium ranelate  135459-87-9
# 310050            parecoxib  198470-84-7
# 310051          brexanolone     516-54-1
# 310052          levorphanol      77-07-6
# 310053  carbasalate calcium    5749-67-7
#
# [310054 rows x 6 columns]

# %% [markdown]
# ##### Mapping MEDDRA to UMLS

# %%
mrconso_meddra_to_umls_df = (
    mrconso_st_df[(
      (mrconso_st_df['SAB'] == 'MDR') # MEDDRA - MDR in UMLS
    )]
    [['CUI', 'STR', 'CODE']]
    .drop_duplicates()
)
mrconso_meddra_to_umls_df['CODE'] = mrconso_meddra_to_umls_df['CODE'].astype(str)

# %%
mrconso_meddra_to_umls_df
# Out:
#                CUI                                   STR      CODE
# 5277      C0000727                         Acute abdomen  10000647
# 5298      C0000727              Syndrome abdominal acute  10042784
# 5301      C0000727              Abdominal syndrome acute  10000096
# 5430      C0000729                      Abdominal cramps  10000057
# 5448      C0000729                       Abdominal cramp  10000056
# ...            ...                                   ...       ...
# 16807021  C5554411                    Digital dermoscopy  10086170
# 16807035  C5554412  Auto-injector viewing window blocked  10086312
# 16807049  C5554413           Tumarkin's otolithic crisis  10086331
# 16807063  C5554414             Allergy to PEGylated drug  10086350
# 16807077  C5554415               Rectal fissure excision  10086368
#
# [90217 rows x 3 columns]

# %%
adverse_eff_df['meddra_code'] = adverse_eff_df['meddra_code'].astype(str)

# %%
adverse_eff_meddra_cui_df = pd.merge(
    adverse_eff_df,
    mrconso_meddra_to_umls_df,
    left_on='meddra_code',
    right_on='CODE'
).rename(columns={'CUI': 'meddra_cui'})

# %%
adverse_eff_meddra_cui_df
# Out:
#         struct_id                         meddra_name meddra_code    id  \
# 0            4185                Abdominal discomfort    10000059  4185
# 1             323                Abdominal discomfort    10000059   323
# 2            4952                Abdominal discomfort    10000059  4952
# 3            5056                Abdominal discomfort    10000059  5056
# 4             633                Abdominal discomfort    10000059   633
# ...           ...                                 ...         ...   ...
# 341936       5123  Scan myocardial perfusion abnormal    10061501  5123
# 341937       5084                Factor IX inhibition    10051778  5084
# 341938       5308          ADAMTS13 activity abnormal    10074493  5308
# 341939       2805      Bladder instillation procedure    10072199  2805
# 341940       4666                 Renal scan abnormal    10061953  4666
#
#                                  name    cas_reg_no meddra_cui  \
# 0                         vemurafenib   918504-65-1   C0232487
# 1                          benzocaine       94-09-7   C0232487
# 2                         canakinumab   914613-48-2   C0232487
# 3                   patiromer calcium  1415477-49-4   C0232487
# 4                         ciclesonide   126544-47-6   C0232487
# ...                               ...           ...        ...
# 341936  technetium Tc 99m tetrofosmin   127455-27-0   C0853562
# 341937              eftrenonacog alfa  1270012-74-2   C0948167
# 341938                   caplacizumab   915810-67-2   C3805010
# 341939                     valrubicin    56124-62-0   C3267064
# 341940                      betiatide   103725-47-9   C0853549
#
#                                        STR      CODE
# 0                     Abdominal discomfort  10000059
# 1                     Abdominal discomfort  10000059
# 2                     Abdominal discomfort  10000059
# 3                     Abdominal discomfort  10000059
# 4                     Abdominal discomfort  10000059
# ...                                    ...       ...
# 341936  Scan myocardial perfusion abnormal  10061501
# 341937                Factor IX inhibition  10051778
# 341938          ADAMTS13 activity abnormal  10074493
# 341939      Bladder instillation procedure  10072199
# 341940                 Renal scan abnormal  10061953
#
# [341941 rows x 9 columns]

# %% [markdown]
# ## Mapping all tables to UMLS CUIs

# %% [markdown]
# ### `pharm_action_df` -> `pharm_action_mapped_df`

# %%
pharm_action_df
# Out:
#          id_x  struct_id type                                   name_x  \
# 0      449782       3024   PA                               Analgesics
# 1      449783       3024   PA                 Analgesics, Non-Narcotic
# 2      449784       3024   PA                 Anti-Inflammatory Agents
# 3      449785       3024   PA  Anti-Inflammatory Agents, Non-Steroidal
# 4      449786       3024   PA                     Antirheumatic Agents
# ...       ...        ...  ...                                      ...
# 25342  463923       4867   PA                        Enzyme Inhibitors
# 25343  463925       4867   PA                  Gastrointestinal Agents
# 25344  463927       4867   PA                   Proton Pump Inhibitors
# 25345  463931       1604   PA                   Anti-Arrhythmia Agents
# 25346  463932       1604   PA                    Cardiovascular Agents
#
#       class_code source  id_y          name_y   cas_reg_no  \
# 0        D000700   MeSH  3024        bevonium   33371-53-8
# 1        D018712   MeSH  3024        bevonium   33371-53-8
# 2        D000893   MeSH  3024        bevonium   33371-53-8
# 3        D000894   MeSH  3024        bevonium   33371-53-8
# 4        D018501   MeSH  3024        bevonium   33371-53-8
# ...          ...    ...   ...             ...          ...
# 25342    D004791   MeSH  4867  dexrabeprazole  177795-60-7
# 25343    D005765   MeSH  4867  dexrabeprazole  177795-60-7
# 25344    D054328   MeSH  4867  dexrabeprazole  177795-60-7
# 25345    D000889   MeSH  1604       lorajmine   47562-08-3
# 25346    D002317   MeSH  1604       lorajmine   47562-08-3
#
#                        class_code_cui            struct_cui
# 0                {C1704390, C0002771}            {C0053533}
# 1                          {C0242937}            {C0053533}
# 2                          {C0003209}            {C0053533}
# 3      {C0003211, C0002773, C0085847}            {C0053533}
# 4      {C0242708, C4505471, C0003191}            {C0053533}
# ...                               ...                   ...
# 25342                      {C0014432}            {C0378482}
# 25343  {C0282187, C0012237, C0017173}            {C0378482}
# 25344                      {C0358591}            {C0378482}
# 25345  {C0003302, C0003195, C0027048}  {C0045017, C0024001}
# 25346            {C4704878, C0007220}  {C0045017, C0024001}
#
# [25347 rows x 11 columns]

# %%
pharm_action_df['class_code_cui'] = (
    pharm_action_df['class_code'].apply(
        lambda x: mesh_to_umls_dict.get(x)
    )
)

pharm_action_df['struct_cui'] = (
    pharm_action_df['cas_reg_no'].apply(
        lambda x: cas_to_cui_dict.get(x)
    )
)

# %%
pharm_action_mapped_df = (
    pharm_action_df
        .explode('class_code_cui')
        .explode('struct_cui')
        .dropna()
)

# %%
pharm_action_mapped_df
# Out:
#          id_x  struct_id type                 name_x class_code source  id_y  \
# 0      449782       3024   PA             Analgesics    D000700   MeSH  3024
# 0      449782       3024   PA             Analgesics    D000700   MeSH  3024
# 0      449782       3024   PA             Analgesics    D000700   MeSH  3024
# 0      449782       3024   PA             Analgesics    D000700   MeSH  3024
# 0      449782       3024   PA             Analgesics    D000700   MeSH  3024
# ...       ...        ...  ...                    ...        ...    ...   ...
# 25346  463932       1604   PA  Cardiovascular Agents    D002317   MeSH  1604
# 25346  463932       1604   PA  Cardiovascular Agents    D002317   MeSH  1604
# 25346  463932       1604   PA  Cardiovascular Agents    D002317   MeSH  1604
# 25346  463932       1604   PA  Cardiovascular Agents    D002317   MeSH  1604
# 25346  463932       1604   PA  Cardiovascular Agents    D002317   MeSH  1604
#
#           name_y  cas_reg_no class_code_cui struct_cui
# 0       bevonium  33371-53-8       C1704390   C0053533
# 0       bevonium  33371-53-8       C1704390   C1112078
# 0       bevonium  33371-53-8       C1704390   C0950157
# 0       bevonium  33371-53-8       C1704390   C0969847
# 0       bevonium  33371-53-8       C1704390   C0106176
# ...          ...         ...            ...        ...
# 25346  lorajmine  47562-08-3       C4704878   C0888886
# 25346  lorajmine  47562-08-3       C4704878   C0888885
# 25346  lorajmine  47562-08-3       C0007220   C0045017
# 25346  lorajmine  47562-08-3       C0007220   C0888886
# 25346  lorajmine  47562-08-3       C0007220   C0888885
#
# [160399 rows x 11 columns]

# %% [markdown]
# ### `adverse_eff_meddra_cui_df` -> `adverse_eff_mapped_df`

# %%
adverse_eff_meddra_cui_df
# Out:
#         struct_id                         meddra_name meddra_code    id  \
# 0            4185                Abdominal discomfort    10000059  4185
# 1             323                Abdominal discomfort    10000059   323
# 2            4952                Abdominal discomfort    10000059  4952
# 3            5056                Abdominal discomfort    10000059  5056
# 4             633                Abdominal discomfort    10000059   633
# ...           ...                                 ...         ...   ...
# 341936       5123  Scan myocardial perfusion abnormal    10061501  5123
# 341937       5084                Factor IX inhibition    10051778  5084
# 341938       5308          ADAMTS13 activity abnormal    10074493  5308
# 341939       2805      Bladder instillation procedure    10072199  2805
# 341940       4666                 Renal scan abnormal    10061953  4666
#
#                                  name    cas_reg_no meddra_cui  \
# 0                         vemurafenib   918504-65-1   C0232487
# 1                          benzocaine       94-09-7   C0232487
# 2                         canakinumab   914613-48-2   C0232487
# 3                   patiromer calcium  1415477-49-4   C0232487
# 4                         ciclesonide   126544-47-6   C0232487
# ...                               ...           ...        ...
# 341936  technetium Tc 99m tetrofosmin   127455-27-0   C0853562
# 341937              eftrenonacog alfa  1270012-74-2   C0948167
# 341938                   caplacizumab   915810-67-2   C3805010
# 341939                     valrubicin    56124-62-0   C3267064
# 341940                      betiatide   103725-47-9   C0853549
#
#                                        STR      CODE  \
# 0                     Abdominal discomfort  10000059
# 1                     Abdominal discomfort  10000059
# 2                     Abdominal discomfort  10000059
# 3                     Abdominal discomfort  10000059
# 4                     Abdominal discomfort  10000059
# ...                                    ...       ...
# 341936  Scan myocardial perfusion abnormal  10061501
# 341937                Factor IX inhibition  10051778
# 341938          ADAMTS13 activity abnormal  10074493
# 341939      Bladder instillation procedure  10072199
# 341940                 Renal scan abnormal  10061953
#
#                                                struct_cui
# 0                                              {C3192263}
# 1       {C0103263, C0055342, C2930485, C0005059, C0002...
# 2                                              {C2718773}
# 3                                              {C4045522}
# 4                                              {C0907850}
# ...                                                   ...
# 341936                                         {C0211492}
# 341937                                         {C4041753}
# 341938                                         {C3713057}
# 341939                                         {C0068314}
# 341940                               {C0672188, C0100672}
#
# [341941 rows x 10 columns]

# %%
adverse_eff_meddra_cui_df['struct_cui'] = (
    adverse_eff_meddra_cui_df['cas_reg_no']
        .apply(lambda x: cas_to_cui_dict.get(x))
)

# %%
adverse_eff_mapped_df = (
    adverse_eff_meddra_cui_df.explode('struct_cui').dropna()
)

# %%
adverse_eff_mapped_df
# Out:
#         struct_id                     meddra_name meddra_code    id  \
# 0            4185            Abdominal discomfort    10000059  4185
# 0            4185            Abdominal discomfort    10000059  4185
# 0            4185            Abdominal discomfort    10000059  4185
# 0            4185            Abdominal discomfort    10000059  4185
# 0            4185            Abdominal discomfort    10000059  4185
# ...           ...                             ...         ...   ...
# 341939       2805  Bladder instillation procedure    10072199  2805
# 341939       2805  Bladder instillation procedure    10072199  2805
# 341939       2805  Bladder instillation procedure    10072199  2805
# 341939       2805  Bladder instillation procedure    10072199  2805
# 341940       4666             Renal scan abnormal    10061953  4666
#
#                name   cas_reg_no meddra_cui                             STR  \
# 0       vemurafenib  918504-65-1   C0232487            Abdominal discomfort
# 0       vemurafenib  918504-65-1   C0232487            Abdominal discomfort
# 0       vemurafenib  918504-65-1   C0232487            Abdominal discomfort
# 0       vemurafenib  918504-65-1   C0232487            Abdominal discomfort
# 0       vemurafenib  918504-65-1   C0232487            Abdominal discomfort
# ...             ...          ...        ...                             ...
# 341939   valrubicin   56124-62-0   C3267064  Bladder instillation procedure
# 341939   valrubicin   56124-62-0   C3267064  Bladder instillation procedure
# 341939   valrubicin   56124-62-0   C3267064  Bladder instillation procedure
# 341939   valrubicin   56124-62-0   C3267064  Bladder instillation procedure
# 341940    betiatide  103725-47-9   C0853549             Renal scan abnormal
#
#             CODE struct_cui
# 0       10000059   C3192267
# 0       10000059   C1832009
# 0       10000059   C4083043
# 0       10000059   C3192263
# 0       10000059   C4310441
# ...          ...        ...
# 341939  10072199   C0724176
# 341939  10072199   C0068314
# 341939  10072199   C1519947
# 341939  10072199   C0133123
# 341940  10061953   C0672188
#
# [2612974 rows x 10 columns]

# %% [markdown]
# ### `indications_df` -> `indications_mapped_df`

# %%
indications_df
# Out:
#          id_x  struct_id  concept_id relationship_name  \
# 0      144492        564    21000286        indication
# 1      146703        564    21001035        indication
# 2      143317        564    21013411     off-label use
# 3      144496        564    21000101        indication
# 4      151436        564    21000110        indication
# ...       ...        ...         ...               ...
# 41815  172341       2316    21003003        indication
# 41816  172342       2316    21003002        indication
# 41817  134154       2959    21000623        indication
# 41818  174027       5392    40249397        indication
# 41819  151427       3290    21003116  contraindication
#
#                                   concept_name  umls_cui  \
# 0                        Gonococcal meningitis  C0153225
# 1                     Streptococcal meningitis  C0154639
# 2                    Pyrexia of unknown origin  C0015970
# 3           Septicemia due to Escherichia coli  C0276088
# 4                         Bacterial septicemia  C0684256
# ...                                        ...       ...
# 41815  Diagnostic Test for Thyroid Dysfunction      None
# 41816               Pituitary Function Studies      None
# 41817       Partial Central Diabetes Insipidus      None
# 41818    Metastatic non-small cell lung cancer  C0278987
# 41819        Sensation Disturbance of Genitals      None
#
#                             snomed_full_name cui_semantic_type  \
# 0                      Gonococcal meningitis              T047
# 1                   Streptococcal meningitis              T047
# 2                  Pyrexia of unknown origin              T184
# 3         Septicemia due to Escherichia coli              T047
# 4                       Bacterial septicemia              T047
# ...                                      ...               ...
# 41815                                   None              None
# 41816                                   None              None
# 41817                                   None              None
# 41818  Metastatic non-small cell lung cancer              T191
# 41819                                   None              None
#
#        snomed_conceptid          doid  id_y          name    cas_reg_no  \
# 0              151004.0          None   564   ceftriaxone    73384-59-5
# 1             4510004.0    DOID:11574   564   ceftriaxone    73384-59-5
# 2             7520000.0          None   564   ceftriaxone    73384-59-5
# 3             9323009.0          None   564   ceftriaxone    73384-59-5
# 4            10001005.0  DOID:0040085   564   ceftriaxone    73384-59-5
# ...                 ...           ...   ...           ...           ...
# 41815               NaN          None  2316    protirelin    24305-27-9
# 41816               NaN          None  2316    protirelin    24305-27-9
# 41817               NaN          None  2959     lypressin       50-57-7
# 41818               NaN          None  5392    capmatinib  1029712-80-8
# 41819               NaN          None  3290  oxyquinoline      148-24-3
#
#                            struct_cui
# 0      {C0007561, C0081371, C3536856}
# 1      {C0007561, C0081371, C3536856}
# 2      {C0007561, C0081371, C3536856}
# 3      {C0007561, C0081371, C3536856}
# 4      {C0007561, C0081371, C3536856}
# ...                               ...
# 41815                      {C0040162}
# 41816                      {C0040162}
# 41817            {C0042413, C0024328}
# 41818                      {C4053698}
# 41819            {C0000665, C0034428}
#
# [41820 rows x 14 columns]

# %%
indications_df['struct_cui'] = (
    indications_df['cas_reg_no'].apply(
        lambda x: cas_to_cui_dict.get(x)
    )
)

# %%
indications_df.head(3)
# Out:
#      id_x  struct_id  concept_id relationship_name               concept_name  \
# 0  144492        564    21000286        indication      Gonococcal meningitis
# 1  146703        564    21001035        indication   Streptococcal meningitis
# 2  143317        564    21013411     off-label use  Pyrexia of unknown origin
#
#    umls_cui           snomed_full_name cui_semantic_type  snomed_conceptid  \
# 0  C0153225      Gonococcal meningitis              T047          151004.0
# 1  C0154639   Streptococcal meningitis              T047         4510004.0
# 2  C0015970  Pyrexia of unknown origin              T184         7520000.0
#
#          doid  id_y         name  cas_reg_no  \
# 0        None   564  ceftriaxone  73384-59-5
# 1  DOID:11574   564  ceftriaxone  73384-59-5
# 2        None   564  ceftriaxone  73384-59-5
#
#                                           struct_cui
# 0  {C1564647, C1564651, C1564652, C0733786, C1564...
# 1  {C1564647, C1564651, C1564652, C0733786, C1564...
# 2  {C1564647, C1564651, C1564652, C0733786, C1564...

# %%
indications_mapped_df = indications_df.explode('struct_cui')

# %%
indications_mapped_df
# Out:
#          id_x  struct_id  concept_id relationship_name  \
# 0      144492        564    21000286        indication
# 0      144492        564    21000286        indication
# 0      144492        564    21000286        indication
# 0      144492        564    21000286        indication
# 0      144492        564    21000286        indication
# ...       ...        ...         ...               ...
# 41819  151427       3290    21003116  contraindication
# 41819  151427       3290    21003116  contraindication
# 41819  151427       3290    21003116  contraindication
# 41819  151427       3290    21003116  contraindication
# 41819  151427       3290    21003116  contraindication
#
#                             concept_name  umls_cui       snomed_full_name  \
# 0                  Gonococcal meningitis  C0153225  Gonococcal meningitis
# 0                  Gonococcal meningitis  C0153225  Gonococcal meningitis
# 0                  Gonococcal meningitis  C0153225  Gonococcal meningitis
# 0                  Gonococcal meningitis  C0153225  Gonococcal meningitis
# 0                  Gonococcal meningitis  C0153225  Gonococcal meningitis
# ...                                  ...       ...                    ...
# 41819  Sensation Disturbance of Genitals      None                   None
# 41819  Sensation Disturbance of Genitals      None                   None
# 41819  Sensation Disturbance of Genitals      None                   None
# 41819  Sensation Disturbance of Genitals      None                   None
# 41819  Sensation Disturbance of Genitals      None                   None
#
#       cui_semantic_type  snomed_conceptid  doid  id_y          name  \
# 0                  T047          151004.0  None   564   ceftriaxone
# 0                  T047          151004.0  None   564   ceftriaxone
# 0                  T047          151004.0  None   564   ceftriaxone
# 0                  T047          151004.0  None   564   ceftriaxone
# 0                  T047          151004.0  None   564   ceftriaxone
# ...                 ...               ...   ...   ...           ...
# 41819              None               NaN  None  3290  oxyquinoline
# 41819              None               NaN  None  3290  oxyquinoline
# 41819              None               NaN  None  3290  oxyquinoline
# 41819              None               NaN  None  3290  oxyquinoline
# 41819              None               NaN  None  3290  oxyquinoline
#
#        cas_reg_no struct_cui
# 0      73384-59-5   C1564647
# 0      73384-59-5   C1564651
# 0      73384-59-5   C1564652
# 0      73384-59-5   C0733786
# 0      73384-59-5   C1564653
# ...           ...        ...
# 41819    148-24-3   C0086760
# 41819    148-24-3   C0000665
# 41819    148-24-3   C1563803
# 41819    148-24-3   C0000666
# 41819    148-24-3   C0917870
#
# [289810 rows x 14 columns]

# %% [markdown]
# ### `drugcentral_export_df` -> `drugcentral_export_mapped_df`

# %% [markdown]
# #### struct_id -> CAS -> CUI

# %%
structid_to_cas_df = tables_dict['structures'][
    tables_dict['structures']['cas_reg_no'].notna()
][['id', 'name', 'cas_reg_no']]

# %%
structid_to_cas_df['struct_cui'] = (
    structid_to_cas_df['cas_reg_no'].apply(
        lambda x: cas_to_cui_dict.get(x)
    )
    .dropna()
)

# %%
structid_to_cas_df
# Out:
#         id                  name    cas_reg_no  \
# 0     5392            capmatinib  1029712-80-8
# 1     5393         selpercatinib  2152628-33-4
# 2     5394            ripretinib  1442472-39-0
# 4     5395  fluoroestradiol F 18    94153-53-4
# 5     5146            ferumoxsil   171544-35-7
# ...    ...                   ...           ...
# 4922  5224             dupilumab  1190264-60-8
# 4923  5109             urokinase     9039-53-6
# 4924  5433             ansuvimab  2375952-29-5
# 4925  5434          margetuximab  1350624-75-7
# 4926  5435             naxitamab  1879925-92-4
#
#                                              struct_cui
# 0     {C5543774, C5543775, C2983764, C4053698, C5543...
# 1              {C5227683, C5435284, C5235396, C4525531}
# 2                                            {C5139749}
# 4                                                   NaN
# 5              {C0257926, C0257928, C0380253, C0380254}
# ...                                                 ...
# 4922           {C3660995, C3660996, C3658854, C4325130}
# 4923  {C0086987, C0701941, C0701940, C0042071, C0086...
# 4924           {C5433066, C5432354, C5432324, C5433440}
# 4925                     {C4053695, C5433071, C2984521}
# 4926           {C4054758, C5423691, C4733494, C5432455}
#
# [4918 rows x 4 columns]

# %%
structid_to_cas_df = structid_to_cas_df.dropna().explode('struct_cui')

# %% [markdown]
# #### Gene name -> CUI

# %%
drugcentral_export_df['GENE_lowcase'] = drugcentral_export_df['GENE'].apply(lambda x: x.lower())

# %%
drugcentral_all_genes_set = set(drugcentral_export_df['GENE_lowcase'])
len(drugcentral_all_genes_set)
# Out:
# 2145

# %%
pref_semtypes = {
    'Amino Acid, Peptide, or Protein',
    'Gene or Genome'
}

# %%
mrconso_gene_st_df = mrconso_st_df[
    (
          mrconso_st_df['STR'].apply(lambda x: str(x).lower()).isin(drugcentral_all_genes_set)
        & mrconso_st_df['sem_types'].apply(lambda x: pref_semtypes.intersection(x))
    )
]
len(mrconso_gene_st_df)
# Out:
# 7526

# %%
mrconso_gene_st_df['STR_lowcase'] = mrconso_gene_st_df['STR'].apply(lambda x: str(x).lower())
# Out:
# /tmp/ipykernel_63770/3667326281.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mrconso_gene_st_df['STR_lowcase'] = mrconso_gene_st_df['STR'].apply(lambda x: str(x).lower())

# %%
len(mrconso_gene_st_df['STR_lowcase'].drop_duplicates())
# Out:
# 1889

# %%
gene_symb_to_cui_agg_df = (
    mrconso_gene_st_df[
        ['CUI', 'STR_lowcase']
    ]
        .groupby('STR_lowcase')
        .agg(set)
        .reset_index()
)

# %%
gene_symb_to_cui_agg_df
# Out:
#      STR_lowcase                             CUI
# 0           aak1                      {C1426329}
# 1           abat                      {C1412057}
# 2          abca1            {C1412058, C3711161}
# 3          abcb1  {C1704939, C1738970, C0376622}
# 4         abcb11            {C1412070, C1313221}
# ...          ...                             ...
# 1884        zacn                      {C1825810}
# 1885         zak                      {C1868689}
# 1886       zap70  {C1705831, C0246976, C1421567}
# 1887    zmpste24                      {C1421586}
# 1888      znf664                      {C1538229}
#
# [1889 rows x 2 columns]

# %% [markdown]
# #### Merging

# %%
drugcentral_export_w_gene_cui_df = (
    pd.merge(
        drugcentral_export_df,
        gene_symb_to_cui_agg_df,
        left_on='GENE_lowcase',
        right_on='STR_lowcase'
    )
    .rename(columns={'CUI': 'gene_CUI'})
    .explode('gene_CUI')
)

# %%
drugcentral_export_w_gene_cui_df
# Out:
#                 DRUG_NAME  STRUCT_ID  \
# 0         levobupivacaine          4
# 1               alosetron        129
# 2              amiodarone        176
# 3           amitriptyline        180
# 4             amodiaquine        186
# ...                   ...        ...
# 21341          evinacumab       5449
# 21342       pegcetacoplan       5457
# 21342       pegcetacoplan       5457
# 21343  piflufolastat F-18       5458
# 21343  piflufolastat F-18       5458
#
#                                              TARGET_NAME  TARGET_CLASS  \
# 0      Potassium voltage-gated channel subfamily H me...   Ion channel
# 1      Potassium voltage-gated channel subfamily H me...   Ion channel
# 2      Potassium voltage-gated channel subfamily H me...   Ion channel
# 3      Potassium voltage-gated channel subfamily H me...   Ion channel
# 4      Potassium voltage-gated channel subfamily H me...   Ion channel
# ...                                                  ...           ...
# 21341                     Angiopoietin-related protein 3      Secreted
# 21342                                      Complement C3  Unclassified
# 21342                                      Complement C3  Unclassified
# 21343                       Glutamate carboxypeptidase 2        Enzyme
# 21343                       Glutamate carboxypeptidase 2        Enzyme
#
#       ACCESSION     GENE             ACT_SOURCE GENE_lowcase STR_lowcase  \
# 0        Q12809    KCNH2                 CHEMBL        kcnh2       kcnh2
# 1        Q12809    KCNH2                 CHEMBL        kcnh2       kcnh2
# 2        Q12809    KCNH2              WOMBAT-PK        kcnh2       kcnh2
# 3        Q12809    KCNH2              WOMBAT-PK        kcnh2       kcnh2
# 4        Q12809    KCNH2                 CHEMBL        kcnh2       kcnh2
# ...         ...      ...                    ...          ...         ...
# 21341    Q9Y5C1  ANGPTL3             DRUG LABEL      angptl3     angptl3
# 21342    P01024       C3  SCIENTIFIC LITERATURE           c3          c3
# 21342    P01024       C3  SCIENTIFIC LITERATURE           c3          c3
# 21343    Q04609    FOLH1                UNKNOWN        folh1       folh1
# 21343    Q04609    FOLH1                UNKNOWN        folh1       folh1
#
#        gene_CUI
# 0      C1416572
# 1      C1416572
# 2      C1416572
# 3      C1416572
# 4      C1416572
# ...         ...
# 21341  C1412401
# 21342  C1332656
# 21342  C1571455
# 21343  C1333570
# 21343  C1310550
#
# [38306 rows x 10 columns]

# %%
drugcentral_export_mapped_df = (
    pd.merge(
        drugcentral_export_w_gene_cui_df,
        structid_to_cas_df,
        left_on='STRUCT_ID',
        right_on='id'
    )
    .dropna()
    .drop_duplicates()
)

# %%
drugcentral_export_mapped_df
# Out:
#                  DRUG_NAME  STRUCT_ID  \
# 0          levobupivacaine          4
# 1          levobupivacaine          4
# 2          levobupivacaine          4
# 3          levobupivacaine          4
# 4          levobupivacaine          4
# ...                    ...        ...
# 238484       pegcetacoplan       5457
# 238485       pegcetacoplan       5457
# 238486       pegcetacoplan       5457
# 238487  piflufolastat F-18       5458
# 238488  piflufolastat F-18       5458
#
#                                               TARGET_NAME  TARGET_CLASS  \
# 0       Potassium voltage-gated channel subfamily H me...   Ion channel
# 1       Potassium voltage-gated channel subfamily H me...   Ion channel
# 2       Potassium voltage-gated channel subfamily H me...   Ion channel
# 3             Sodium channel protein type 1 subunit alpha   Ion channel
# 4             Sodium channel protein type 1 subunit alpha   Ion channel
# ...                                                   ...           ...
# 238484                                      Complement C3  Unclassified
# 238485                                      Complement C3  Unclassified
# 238486                                      Complement C3  Unclassified
# 238487                       Glutamate carboxypeptidase 2        Enzyme
# 238488                       Glutamate carboxypeptidase 2        Enzyme
#
#        ACCESSION   GENE             ACT_SOURCE GENE_lowcase STR_lowcase  \
# 0         Q12809  KCNH2                 CHEMBL        kcnh2       kcnh2
# 1         Q12809  KCNH2                 CHEMBL        kcnh2       kcnh2
# 2         Q12809  KCNH2                 CHEMBL        kcnh2       kcnh2
# 3         P35498  SCN1A              WOMBAT-PK        scn1a       scn1a
# 4         P35498  SCN1A              WOMBAT-PK        scn1a       scn1a
# ...          ...    ...                    ...          ...         ...
# 238484    P01024     C3  SCIENTIFIC LITERATURE           c3          c3
# 238485    P01024     C3  SCIENTIFIC LITERATURE           c3          c3
# 238486    P01024     C3  SCIENTIFIC LITERATURE           c3          c3
# 238487    Q04609  FOLH1                UNKNOWN        folh1       folh1
# 238488    Q04609  FOLH1                UNKNOWN        folh1       folh1
#
#         gene_CUI    id                name    cas_reg_no struct_cui
# 0       C1416572     4     levobupivacaine    27262-47-1   C0873119
# 1       C1416572     4     levobupivacaine    27262-47-1   C0875986
# 2       C1416572     4     levobupivacaine    27262-47-1   C0873118
# 3       C1419856     4     levobupivacaine    27262-47-1   C0873119
# 4       C1419856     4     levobupivacaine    27262-47-1   C0875986
# ...          ...   ...                 ...           ...        ...
# 238484  C1332656  5457       pegcetacoplan  2019171-69-6   C5418501
# 238485  C1571455  5457       pegcetacoplan  2019171-69-6   C5455506
# 238486  C1571455  5457       pegcetacoplan  2019171-69-6   C5418501
# 238487  C1333570  5458  piflufolastat F-18  1207181-29-0   C3492634
# 238488  C1310550  5458  piflufolastat F-18  1207181-29-0   C3492634
#
# [236196 rows x 14 columns]

# %% [markdown]
# ### `drug_target_artificial_df` -> `drug_target_artificial_mapped_df`

# %%
drug_target_artificial_mapped_df = pd.merge(
    indications_mapped_df[['snomed_full_name', 'umls_cui', 'struct_id', 'name', 'cas_reg_no', 'struct_cui']],
    drugcentral_export_mapped_df[['DRUG_NAME', 'STRUCT_ID', 'TARGET_NAME', 'GENE', 'gene_CUI', 'struct_cui']],
    left_on='struct_cui',
    right_on='struct_cui',
    how='inner'
).dropna()

# %%
drug_target_artificial_mapped_df
# Out:
#                               snomed_full_name  umls_cui  struct_id  \
# 0                        Gonococcal meningitis  C0153225        564
# 1                        Gonococcal meningitis  C0153225        564
# 2                        Gonococcal meningitis  C0153225        564
# 3                     Streptococcal meningitis  C0154639        564
# 4                     Streptococcal meningitis  C0154639        564
# ...                                        ...       ...        ...
# 6001063  Metastatic non-small cell lung cancer  C0278987       5392
# 6001064  Metastatic non-small cell lung cancer  C0278987       5392
# 6001065  Metastatic non-small cell lung cancer  C0278987       5392
# 6001066  Metastatic non-small cell lung cancer  C0278987       5392
# 6001067  Metastatic non-small cell lung cancer  C0278987       5392
#
#                 name    cas_reg_no struct_cui    DRUG_NAME  STRUCT_ID  \
# 0        ceftriaxone    73384-59-5   C1564647  ceftriaxone        564
# 1        ceftriaxone    73384-59-5   C1564647  ceftriaxone        564
# 2        ceftriaxone    73384-59-5   C1564647  ceftriaxone        564
# 3        ceftriaxone    73384-59-5   C1564647  ceftriaxone        564
# 4        ceftriaxone    73384-59-5   C1564647  ceftriaxone        564
# ...              ...           ...        ...          ...        ...
# 6001063   capmatinib  1029712-80-8   C5244866   capmatinib       5392
# 6001064   capmatinib  1029712-80-8   C5244866   capmatinib       5392
# 6001065   capmatinib  1029712-80-8   C5244866   capmatinib       5392
# 6001066   capmatinib  1029712-80-8   C5244866   capmatinib       5392
# 6001067   capmatinib  1029712-80-8   C5244866   capmatinib       5392
#
#                                TARGET_NAME GENE  gene_CUI
# 0                     D-amino-acid oxidase  DAO  C1413903
# 1                     D-amino-acid oxidase  DAO  C1450094
# 2                     D-amino-acid oxidase  DAO  C1412100
# 3                     D-amino-acid oxidase  DAO  C1413903
# 4                     D-amino-acid oxidase  DAO  C1450094
# ...                                    ...  ...       ...
# 6001063  Hepatocyte growth factor receptor  MET  C1419433
# 6001064  Hepatocyte growth factor receptor  MET  C1417123
# 6001065  Hepatocyte growth factor receptor  MET  C1704823
# 6001066  Hepatocyte growth factor receptor  MET  C1822773
# 6001067  Hepatocyte growth factor receptor  MET  C0025646
#
# [5574054 rows x 11 columns]

# %% [markdown]
# ## Extracting pairs of UMLS terms

# %%
adverse_eff_mapped_pairs_df = (
    adverse_eff_mapped_df[
        ['struct_cui', 'meddra_cui']
    ]
    .dropna()
)

adverse_eff_mapped_pairs = list({
    tuple(sorted(p)) for p in list(
        zip(
            adverse_eff_mapped_pairs_df['struct_cui'],
            adverse_eff_mapped_pairs_df['meddra_cui']
        )
    )
})
len(adverse_eff_mapped_pairs)
# Out:
# 2338731

# %%
pharm_action_mapped_pairs_df = (
    pharm_action_mapped_df[
        ['struct_cui', 'class_code_cui']
    ]
    .dropna()
)

pharm_action_mapped_pairs = list({
    tuple(sorted(p)) for p in list(
        zip(
            pharm_action_mapped_pairs_df['struct_cui'],
            pharm_action_mapped_pairs_df['class_code_cui']
        )
    )
})
len(pharm_action_mapped_pairs)
# Out:
# 158387

# %%
indications_mapped_pairs_df = (
    indications_mapped_df[
        ['struct_cui', 'umls_cui']
    ]
    .dropna()
)

indications_mapped_pairs = list({
    tuple(sorted(p)) for p in list(
        zip(
            indications_mapped_pairs_df['struct_cui'],
            indications_mapped_pairs_df['umls_cui']
        )
    )
})
len(indications_mapped_pairs)
# Out:
# 257304

# %%
drugcentral_export_mapped_pairs_df = (
    drugcentral_export_mapped_df[
        ['struct_cui', 'gene_CUI']
    ]
    .dropna()
)

drugcentral_export_mapped_pairs = list({
    tuple(sorted(p)) for p in list(
        zip(
            drugcentral_export_mapped_pairs_df['struct_cui'],
            drugcentral_export_mapped_pairs_df['gene_CUI']
        )
    )
})
len(drugcentral_export_mapped_pairs)
# Out:
# 188791

# %%
drug_target_artificial_mapped_pairs_df = (
    drug_target_artificial_mapped_df[
        ['struct_cui', 'gene_CUI']
    ]
    .dropna()
)

drug_target_artificial_mapped_pairs = list({
    tuple(sorted(p)) for p in list(
        zip(
            drug_target_artificial_mapped_pairs_df['struct_cui'],
            drug_target_artificial_mapped_pairs_df['gene_CUI']
        )
    )
})
len(drug_target_artificial_mapped_pairs)
# Out:
# 168860

# %% [markdown]
# ### Summarizing and saving

# %%
len(adverse_eff_mapped_pairs)
# Out:
# 2338731

# %%
len(pharm_action_mapped_pairs)
# Out:
# 158387

# %%
len(indications_mapped_pairs)
# Out:
# 257304

# %%
len(drugcentral_export_mapped_pairs)
# Out:
# 188791

# %%
len(drug_target_artificial_mapped_pairs)
# Out:
# 168860

# %%
drugcentral_pairs_all = set()

for pair_list in tqdm(
    [
        adverse_eff_mapped_pairs,
        pharm_action_mapped_pairs,
        indications_mapped_pairs,
        drugcentral_export_mapped_pairs,
        drug_target_artificial_mapped_pairs
    ]
):
    drugcentral_pairs_all.update(pair_list)
    
len(drugcentral_pairs_all)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 10.02it/s]
# 2900561

# %%
with open('../../benchmark_data/01_cui_pairs_json/drugcentral_cui_pairs.json', 'w') as f:
    json.dump(list(drugcentral_pairs_all), f)
